# %% [markdown]
# # DQN для игр от Atari

# %% [markdown]
# Есть несколько версий игры Atari Pong в библиотеке Gymnasium. Используем, например, версию
#
#     env = gym.make("ALE/Pong-v5")
#
# Для обучения агента используем алгоритм DQN с буфером опыта и двумя ИНС. Реализация алгоритма DQN аналогична уже сделанной реализации DQN в файле `2.4.2 RL_DoubleDQN_PyTorch.ipynb` с шагом предобработки.
#
# В целом алгоритм следует основным шагам алгоритма статьи 2013 года
#
#     Playing Atari with Deep Reinforcement Learning
#
# где впервые глубокое обучение и Q-обучение были успешно совмещены.

# %% [markdown]
# Подгрузим необходимые библиотеки.

# %%
import os 
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# для избежания ошибки с plt
#https://programmerah.com/solved-omp-error-15-initializing-libiomp5md-dll-but-found-libiomp5md-dll-already-initialized-35360/
import matplotlib.pyplot as plt
import random
import numpy as np

import torch

import torch.nn as nn
import torch.nn.functional as F

import gymnasium as gym

import ale_py
# регистрируем среды в gym
gym.register_envs(ale_py)

import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# При работе в Google Colab можно использовать CUDA-вычисления.

# %%
# создание экземпляра среды
env = gym.make("ALE/Pong-v5")

# обнуление среды и получение начального состояния
state, _ = env.reset()
print("Начальное состояние:")
plt.imshow(state)

# возможные действия
print("Количество действий:", env.action_space.n)

# выведем описания пространств состояний и действий
print("Пространство состояний:", env.observation_space)
print("Пространство действий:", env.action_space)
# Out:
# Начальное состояние:
# Количество действий: 6
# Пространство состояний: Box(0, 255, (210, 160, 3), uint8)
# Пространство действий: Discrete(6)

# %%
# Параметры для старой версии v4 + NoFrameskip.
env = gym.make("ALE/Pong-v5", frameskip = 1, difficulty = 0, repeat_action_probability = 0.0)
state, _ = env.reset()
for i in range(100):
    state,_,_,_,_ = env.step(1)
plt.imshow(state)

# %%
print(env.unwrapped.get_action_meanings())
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %% [markdown]
# Для обработки формируемых средой изображений используем ряд обёрток, которые можно найти в пакете `gymnasium.wrappers`.
# Например, обёртка `AtariPreprocessing` позволяет снизить размер изображения с `210*160*3` до серого изображения `84*84`.
# Эта функция также масштабирует пиксели из интервала (0,255) до (0.0, 1.0) с параметром `scale_obs=True`.
#
# Ещё одна обёртка `FrameStack` позволяет получить массив из 4 последовательных изображений. Это необходимо, чтобы агент мог уловить текущую динамику объектов в игре.

# %%
from gymnasium.wrappers import AtariPreprocessing
from gymnasium.wrappers import FrameStackObservation

def make_env(env_name, render = None):
    env = gym.make(env_name, frameskip = 1, difficulty = 0, render_mode = render, repeat_action_probability = 0.0)
    env = AtariPreprocessing(env, noop_max=10, frame_skip=4, screen_size=84, grayscale_obs = True, scale_obs=True)
    env = FrameStackObservation(env, stack_size=4)
    return env

# %%
env = make_env("ALE/Pong-v5")
state, _ = env.reset()    
print(state.shape)
plt.imshow(np.transpose(state,[1,0,2]).reshape(84,-1))
# Out:
# (4, 84, 84)

# %% [markdown]
# Пример ИНС, которая будет использоваться для приближения Q-функции.

# %%
class QNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(QNetwork, self).__init__()
        self.input_dim = input_dim
        channels, _, _ = input_dim

        # 3 свёрточных слоя
        self.l1 = nn.Sequential(
            nn.Conv2d(channels, 32, kernel_size=8, stride=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
        )

        # нахождения выходной размерности для подачи на линейный слой
        conv_output_size = self.conv_output_dim()
        lin1_output_size = 128

        # 2 полносвязных слоя
        self.l2 = nn.Sequential(
            nn.Linear(conv_output_size, lin1_output_size),
            nn.ReLU(),
            nn.Linear(lin1_output_size, 64),
            nn.ReLU(),
            nn.Linear(64, output_dim)
        )

    def conv_output_dim(self):
        x = torch.zeros(1, *self.input_dim)
        x = self.l1(x)
        return int(np.prod(x.shape))

    # определения функции прямого прохождения сигнала по сети
    def forward(self, x):
        x = self.l1(x)
        x = x.view(x.shape[0], -1)
        actions = self.l2(x)

        return actions

# %%
64*11*11*128+128
# Out:
# 991360

# %%
from torchsummary import summary

model = QNetwork((4, 84, 84), env.action_space.n).to(device)
model_target = QNetwork((4, 84, 84), env.action_space.n).to(device)

summary(model, (4,84,84))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 21, 21]           8,224
#               ReLU-2           [-1, 32, 21, 21]               0
#             Conv2d-3           [-1, 64, 11, 11]          32,832
#               ReLU-4           [-1, 64, 11, 11]               0
#             Conv2d-5           [-1, 64, 11, 11]          36,928
#               ReLU-6           [-1, 64, 11, 11]               0
#             Linear-7                  [-1, 128]         991,360
#               ReLU-8                  [-1, 128]               0
#             Linear-9                   [-1, 64]           8,256
#              ReLU-10                   [-1, 64]               0
#            Linear-11                    [-1, 6]             390
# ================================================================
# Total params: 1,077,990
# Trainable params: 1,077,990
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 0.45
# Params size (MB): 4.11
# Estimated Total Size (MB): 4.67
# ----------------------------------------------------------------

# %%
env = make_env("ALE/Pong-v5", render = 'human')
env = gym.wrappers.RecordEpisodeStatistics(env)

state, _ = env.reset()

while True:
    action = env.action_space.sample()    
    state, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        break
 
print("Доход:", env.returns_queue[-1])
env.close()

# %%
env = make_env("ALE/Pong-v5", render = 'human')
env.close()
env
# Out:
# <FrameStackObservation<AtariPreprocessing<OrderEnforcing<PassiveEnvChecker<AtariEnv<ALE/Pong-v5>>>>>>

# %% [markdown]
# ### Код алгоритма

# %%
from collections import deque

def data_to_tensors(state, action, reward, next_state, terminated): 
    # перевод данных в тензоры
    state = torch.tensor(state).float()
    action = torch.tensor(action).long()
    reward = torch.tensor(reward).float()
    next_state = torch.tensor(next_state).float()
    terminated = torch.tensor(terminated).float()
    
    return state, action, reward, next_state, terminated
    
class ReplayBuffer:
    def __init__(self, size):
        self.size = size  # максимальное число элементов
        self.buffer = deque(maxlen=size)

    def __len__(self):
        return len(self.buffer)

    def add(self, state, action, reward, next_state, terminated):
        item = data_to_tensors(state, action, reward, next_state, terminated)
        self.buffer.append(item)


    def sample(self, batch_size):
        samples = random.sample(self.buffer, k=batch_size)
        # из samples выбрать отдельно состояния, действия, вознаграждения, новые состояния
        # zip выдаёт тип zip, затем приведение к списку
        states, actions, rewards, next_states, dones = list(zip(*samples))
        # получим список состояний, действий и т.д.

        states = torch.stack(states).to(device)
        actions = torch.stack(actions).to(device)
        rewards = torch.stack(rewards).to(device)
        next_states = torch.stack(next_states).to(device)
        dones = torch.stack(dones).to(device)

        return states, actions, rewards, next_states, dones

# %% [markdown]
# Для успешного обучения важно выбрать достаточно малый шаг обучения $\alpha$

# %%
class DQNAgent():

    def __init__(self, env, model, model_target, alpha=0.00025, gamma=0.99, epsilon=0.1):
        # инициализация полей
        self.alpha = alpha
        self.epsilon = epsilon
        self.gamma = torch.tensor(gamma).float().to(device)
        self.nA = env.action_space.n

        # инициализация сетей
        self.Q_train = model
        self.Q_target = model_target
        self.optimizer = torch.optim.Adam(self.Q_train.parameters(), lr=self.alpha)

        # буфер памяти
        self.memory = ReplayBuffer(BUFFER_SIZE)
        # счётчик, для определения момента обновления параметров сети
        self.t_step = 0

    def best_action(self, state):
        # состояние в тензор
        state = torch.tensor(state).float().to(device)
        # вычисляем отклик ИНС, используем torch.no_grad(), чтобы не вычислялись градиенты  
        with torch.no_grad():
            q_values = self.Q_train(state.unsqueeze(0)).squeeze(0)
        return torch.argmax(q_values).cpu().item() 
        
    def get_action(self, state):
        # eps-жадный выбор (или случайный выбор для заполнения буфера)
        if np.random.rand() < self.epsilon or self.t_step < BUFFER_SIZE:
            return np.random.choice(self.nA)
        return self.best_action(state)

    def update(self, state, action, reward, next_state, done):
        # Сохранить строку данных (s,a,r,s',done) в буфер
        self.memory.add(state, action, reward, next_state, done)

        self.t_step = self.t_step + 1
        # обучаться каждые UPDATE_EVERY шагов.
        if self.t_step  % UPDATE_EVERY == 0:
            #  если в памяти достаточно много сэмплов, то обучаться
            if len(self.memory) > BATCH_SIZE:
                self.learn()

        if self.t_step % 20000 == 0:
            torch.save(self.Q_target, 'savedModels/pong_simple_'+str(self.t_step)+'.pkl')
            print("Net saved!")

    def learn(self):
        # получаем данные из буфера
        states, actions, rewards, next_states, dones = self.memory.sample(BATCH_SIZE)

        # Находим max Q_2(s,a), вычисляем отклик второй ИНС без обучения,
        with torch.no_grad():
            q_next_states = agent.Q_target(next_states)
        # вычисляем целевые значения для обучения первой ИНС (max в каждой строке, затем выбор значений)
        q_targets_next = q_next_states.max(1)[0]
        q_targets = rewards + self.gamma * q_targets_next * (1 - dones)
        # Обучение: находим отклики первой ИНС на пакет состояний
        # из каждой строки [Q(s,a1), Q(s,a2),...] выбираем Q(s,a) в соответствии с фактическими сделанными действиями
        q_expected = agent.Q_train(states).gather(1, actions.unsqueeze(1)).squeeze(1)

        # функция ошибки и шаг градиентного спуска
        #loss = F.huber_loss(q_expected, q_targets)
        loss = F.mse_loss(q_expected, q_targets)
        self.optimizer.zero_grad()
        loss.backward()

        # срез градиентов по норме
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1)
        self.optimizer.step()

        # обновить целевую сеть
        if self.t_step % UPDATE_EVERY_Q == 0:
            agent.Q_target.load_state_dict(agent.Q_train.state_dict())
            print("Net updated!")

# %%
def DQN_control(env, agent, num_episodes=10000):
    # Инициализация
    epsilon_min = 0.05
    epsilon_max = 1.0
    epsilon_greedy_frames = 1000000.0  #Число фреймов с исследованием (когда eps > минимального)
    epsilon_interval = epsilon_max - epsilon_min  # интервал для уменьшения eps
    agent.epsilon = max(epsilon_min, epsilon_max - epsilon_interval / epsilon_greedy_frames * agent.t_step)
    start_time = time.time()  # счётчик времени выполнения
    #open("logs/gains_pong.txt", 'w+').close()   # очистить файл записи доходов за эпизод
    with open('logs/gains_pong.txt', 'a') as f:
        f.write("NewLearn")
        f.write('\n')
    
    for i in range(num_episodes):
        state, _ = env.reset()
        while True:
            action = agent.get_action(state)
            next_state, reward, terminated, truncated, _ = env.step(action)
            agent.update(state, action, reward, next_state, terminated)
            state = next_state
            if terminated or truncated:
                break

        # Снижение eps
        agent.epsilon = max(epsilon_min, epsilon_max - epsilon_interval / epsilon_greedy_frames * agent.t_step)
         
        # Запись дохода, вывод информации
        running_gain = np.mean(np.array(env.return_queue)[-10:])
        if i % 2 ==0:
            print("\rСредний доход: {:.2f} к эпизоду {}, фрейм {}, eps {}".format(running_gain, i, agent.t_step, agent.epsilon))
            print("--- {} сек ---".format(time.time() - start_time))
            start_time = time.time()
            
        with open('logs/gains_pong.txt', 'a') as f:
            f.write(str(running_gain))
            f.write('\n')

# %%
# Гиперпараметры
BUFFER_SIZE = 40000  # размер буфера памяти
BATCH_SIZE = 32       # размер пакета
UPDATE_EVERY = 3        # как часто проводить обучение сети
UPDATE_EVERY_Q = 5000     # как часто обновлять параметры целевой сети

# %%
env = make_env("ALE/Pong-v5")
env = gym.wrappers.RecordEpisodeStatistics(env)
agent = DQNAgent(env, model, model_target)

# %%
DQN_control(env, agent, num_episodes = 10)
# Out:
# Средний доход: -21.00 к эпизоду 0, фрейм 790, eps 0.9992495
# --- 6.899796485900879 сек ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 DQN_control(env, agent, num_episodes = 10)
#
# Cell In[28], line 19, in DQN_control(env, agent, num_episodes)
#      17 action = agent.get_action(state)
#      18 next_state, reward, terminated, truncated, _ = env.step(action)
# ---> 19 agent.update(state, action, reward, next_state, terminated)
#      20 state = next_state
#      21 if terminated or truncated:
#
# Cell In[34], line 43, in DQNAgent.update(self, state, action, reward, next_state, done)
#      40 if self.t_step  % UPDATE_EVERY == 0:
#      41     #  если в памяти достаточно много сэмплов, то обучаться
#      42     if len(self.memory) > BATCH_SIZE:
# ---> 43         self.learn()
#      45 if self.t_step % 20000 == 0:
#      46     torch.save(self.Q_target, 'savedModels/pong_simple_'+str(self.t_step)+'.pkl')
#
# Cell In[34], line 61, in DQNAgent.learn(self)
#      58 q_targets = rewards + self.gamma * q_targets_next * (1 - dones)
#      59 # Обучение: находим отклики первой ИНС на пакет состояний
#      60 # из каждой строки [Q(s,a1), Q(s,a2),...] выбираем Q(s,a) в соответствии с фактическими сделанными действиями
# ---> 61 q_expected = agent.Q_train(states).gather(1, actions.unsqueeze(1)).squeeze(1)
#      63 # функция ошибки и шаг градиентного спуска
#      64 #loss = F.huber_loss(q_expected, q_targets)
#      65 loss = F.mse_loss(q_expected, q_targets)
#
# File D:\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[15], line 39, in QNetwork.forward(self, x)
#      37 x = self.l1(x)
#      38 x = x.view(x.shape[0], -1)
# ---> 39 actions = self.l2(x)
#      41 return actions
#
# File D:\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\anaconda3\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File D:\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Тест обученного агента
#
# Подгрузим сохранённую модель.

# %%
agent = DQNAgent(env, model, model_target)

agent.Q_train = torch.load('savedModels/pong_simple_'+str(1500000)+'.pkl',map_location=torch.device('cpu'),weights_only=False).to(device)
agent.Q_train.eval()
agent.Q_target = torch.load('savedModels/pong_simple_'+str(1500000)+'.pkl',map_location=torch.device('cpu'),weights_only=False).to(device)
agent.Q_target.eval()
# Out:
# QNetwork(
#   (l1): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#   )
#   (l2): Sequential(
#     (0): Linear(in_features=7744, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=6, bias=True)
#   )
# )

# %%
env = make_env("ALE/Pong-v5", render = 'human')
env = gym.wrappers.RecordEpisodeStatistics(env)

state, _ = env.reset()

while True:
    state, reward, terminated, truncated, _ = env.step(agent.best_action(state)) 
    if terminated or truncated:
        break
        
print("Доход:", env.return_queue[-1])
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 7
#       4 state, _ = env.reset()
#       6 while True:
# ----> 7     state, reward, terminated, truncated, _ = env.step(agent.best_action(state))
#       8     if terminated or truncated:
#       9         break
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:513, in RecordEpisodeStatistics.step(self, action)
#     509 def step(
#     510     self, action: ActType
#     511 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     512     """Steps through the environment, recording the episode statistics."""
# --> 513     obs, reward, terminated, truncated, info = super().step(action)
#     515     self.episode_returns += reward
#     516     self.episode_lengths += 1
#
# File D:\anaconda3\Lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\stateful_observation.py:416, in FrameStackObservation.step(self, action)
#     405 def step(
#     406     self, action: WrapperActType
#     407 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     408     """Steps through the environment, appending the observation to the frame buffer.
#     409
#     410     Args:
#    (...)
#     414         Stacked observations, reward, terminated, truncated, and info from the environment
#     415     """
# --> 416     obs, reward, terminated, truncated, info = self.env.step(action)
#     417     self.obs_queue.append(obs)
#     419     updated_obs = deepcopy(
#     420         concatenate(self.env.observation_space, self.obs_queue, self.stacked_obs)
#     421     )
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\atari_preprocessing.py:162, in AtariPreprocessing.step(self, action)
#     159 total_reward, terminated, truncated, info = 0.0, False, False, {}
#     161 for t in range(self.frame_skip):
# --> 162     _, reward, terminated, truncated, info = self.env.step(action)
#     163     total_reward += reward
#     164     self.game_over = terminated
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File D:\anaconda3\Lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File D:\anaconda3\Lib\site-packages\ale_py\env.py:299, in AtariEnv.step(self, action)
#     297 reward = 0.0
#     298 for _ in range(frameskip):
# --> 299     reward += self.ale.act(action_idx, strength)
#     301 is_terminal = self.ale.game_over(with_truncation=False)
#     302 is_truncated = self.ale.game_truncated()
#
# KeyboardInterrupt:

# %%
env = gym.make("ALE/Pong-v5", render_mode = 'human')
env.close()
env
# Out:
# <OrderEnforcing<PassiveEnvChecker<AtariEnv<ALE/Pong-v5>>>>

# %% [markdown]
# #### График обучения

# %%
with open('logs/gains_pong.txt') as file:
    file_contents = file.read()
    file.close()

f1 = file_contents.split()
gains = []
for w in f1[1:]:
    gains.append(float(w))

# %%
import matplotlib.pyplot as plt
import numpy as np


y_ticks = np.arange(-21.0,21.0,2.0)
plt.yticks(y_ticks, y_ticks)
plt.plot(gains)
plt.show()

# %% [markdown]
# # Обучение для большей сложности

# %% [markdown]
# Есть случайное повторение действия. Меньше платформы.

# %%
from gymnasium.wrappers import AtariPreprocessing
from gymnasium.wrappers import FrameStackObservation

def make_env(env_name, render = None):
    env = gym.make(env_name, frameskip=1, render_mode = render, difficulty = 3)
    env = AtariPreprocessing(env, noop_max=10, frame_skip=4, screen_size=84, grayscale_obs = True, scale_obs=True)
    env = FrameStackObservation(env, stack_size=4)
    return env

# %%
class DQNAgent():

    def __init__(self, env, model, model_target, alpha=0.00025, gamma=0.99, epsilon=0.1):
        # инициализация полей
        self.alpha = alpha
        self.epsilon = epsilon
        self.gamma = torch.tensor(gamma).float().to(device)
        self.nA = env.action_space.n

        # инициализация сетей
        self.Q_train = model
        self.Q_target = model_target
        self.optimizer = torch.optim.Adam(self.Q_train.parameters(), lr=self.alpha)

        # буфер памяти
        self.memory = ReplayBuffer(BUFFER_SIZE)
        # счётчик, для определения момента обновления параметров сети
        self.t_step = 0

    def best_action(self, state):
        # состояние в тензор
        state = torch.tensor(state).float().to(device)
        # вычисляем отклик ИНС, используем torch.no_grad(), чтобы не вычислялись градиенты  
        with torch.no_grad():
            q_values = self.Q_train(state.unsqueeze(0)).squeeze(0)
        return torch.argmax(q_values).cpu().item() 
        
    def get_action(self, state):
        # eps-жадный выбор (или случайный выбор для заполнения буфера)
        if np.random.rand() < self.epsilon or self.t_step < BUFFER_SIZE:
            return np.random.choice(self.nA)
        return self.best_action(state)

    def update(self, state, action, reward, next_state, done):
        # Сохранить строку данных (s,a,r,s',done) в буфер
        self.memory.add(state, action, reward, next_state, done)

        self.t_step = self.t_step + 1
        # обучаться каждые UPDATE_EVERY шагов.
        if self.t_step  % UPDATE_EVERY == 0:
            #  если в памяти достаточно много сэмплов, то обучаться
            if len(self.memory) > BATCH_SIZE:
                self.learn()

        if self.t_step % 20000 == 0:
            torch.save(self.Q_target, 'savedModels/pong_py_'+str(self.t_step)+'.pkl')
            print("Net saved!")

    def learn(self):
        # получаем данные из буфера
        states, actions, rewards, next_states, dones = self.memory.sample(BATCH_SIZE)

        # Находим max Q_2(s,a), вычисляем отклик второй ИНС без обучения,
        with torch.no_grad():
            q_next_states = agent.Q_target(next_states)
        # вычисляем целевые значения для обучения первой ИНС (max в каждой строке, затем выбор значений)
        q_targets_next = q_next_states.max(1)[0]
        q_targets = rewards + self.gamma * q_targets_next * (1 - dones)
        # Обучение: находим отклики первой ИНС на пакет состояний
        # из каждой строки [Q(s,a1), Q(s,a2),...] выбираем Q(s,a) в соответствии с фактическими сделанными действиями
        q_expected = agent.Q_train(states).gather(1, actions.unsqueeze(1)).squeeze(1)

        # функция ошибки и шаг градиентного спуска
        #loss = F.huber_loss(q_expected, q_targets)
        loss = F.mse_loss(q_expected, q_targets)
        self.optimizer.zero_grad()
        loss.backward()

        # срез градиентов по норме
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1)
        self.optimizer.step()

        # обновить целевую сеть
        if self.t_step % UPDATE_EVERY_Q == 0:
            agent.Q_target.load_state_dict(agent.Q_train.state_dict())
            print("Net updated!")

# %%
# Гиперпараметры
BUFFER_SIZE = 40000  # размер буфера памяти
BATCH_SIZE = 48        # размер пакета
UPDATE_EVERY = 3        # как часто проводить обучение сети
UPDATE_EVERY_Q = 5000     # как часто обновлять параметры целевой сети

# %%
env = make_env("ALE/Pong-v5")
env = gym.wrappers.RecordEpisodeStatistics(env)
agent = DQNAgent(env, model, model_target, alpha=0.00025)

# %%
def DQN_control(env, agent, num_episodes=10000):
    # Инициализация
    epsilon_min = 0.05
    epsilon_max = 1.0
    epsilon_greedy_frames = 2000000.0  #Число фреймов с исследованием (когда eps > минимального)
    epsilon_interval = epsilon_max - epsilon_min  # интервал для уменьшения eps
    agent.epsilon = max(epsilon_min, epsilon_max - epsilon_interval / epsilon_greedy_frames * agent.t_step)
    start_time = time.time()  # счётчик времени выполнения
    #open("logs/gains_pong.txt", 'w+').close()   # очистить файл записи доходов за эпизод
    with open('logs/gains_pong_2.txt', 'a') as f:
        f.write("NewLearn")
        f.write('\n')
    
    for i in range(num_episodes):
        state, _ = env.reset()
        while True:
            action = agent.get_action(state)
            next_state, reward, terminated, truncated, _ = env.step(action)
            agent.update(state, action, reward, next_state, terminated)
            state = next_state
            if terminated or truncated:
                break

        # Снижение eps
        agent.epsilon = max(epsilon_min, epsilon_max - epsilon_interval / epsilon_greedy_frames * agent.t_step)

        # Запись дохода, вывод информации
        running_gain = np.mean(np.array(env.return_queue)[-10:])
        if i % 2 ==0:
            print("\rСредний доход: {:.2f} к эпизоду {}, фрейм {}, eps {}".format(running_gain, i, agent.t_step, agent.epsilon))
            print("--- {} сек ---".format(time.time() - start_time))
            start_time = time.time()
            
        with open('logs/gains_pong_2.txt', 'a') as f:
            f.write(str(running_gain))
            f.write('\n')

# %%
DQN_control(env, agent, num_episodes = 2000)
# Out:
# Средний доход: -19.00 к эпизоду 0, фрейм 937, eps 0.999554925
# --- 3.0910820960998535 сек ---
# Средний доход: -19.67 к эпизоду 2, фрейм 2681, eps 0.998726525
# --- 4.903890609741211 сек ---
# Средний доход: -19.80 к эпизоду 4, фрейм 4549, eps 0.997839225
# --- 5.28167462348938 сек ---
# Средний доход: -20.14 к эпизоду 6, фрейм 6076, eps 0.9971139
# --- 4.301945686340332 сек ---
# Средний доход: -20.00 к эпизоду 8, фрейм 8062, eps 0.99617055
# --- 5.75218391418457 сек ---
# Средний доход: -19.90 к эпизоду 10, фрейм 10164, eps 0.9951721
# --- 5.9975221157073975 сек ---
# Средний доход: -19.50 к эпизоду 12, фрейм 12196, eps 0.9942069
# --- 7.253771543502808 сек ---
# Средний доход: -19.40 к эпизоду 14, фрейм 14012, eps 0.9933443
# --- 5.697290658950806 сек ---
# Net updated!
# Средний доход: -19.20 к эпизоду 16, фрейм 15814, eps 0.99248835
# --- 5.276406526565552 сек ---
# Средний доход: -19.00 к эпизоду 18, фрейм 18038, eps 0.99143195
# --- 6.163651943206787 сек ---
# Средний доход: -19.20 к эпизоду 20, фрейм 19902, eps 0.99054655
# --- 5.410947799682617 сек ---
# Net saved!
# Средний доход: -19.60 к эпизоду 22, фрейм 21700, eps 0.9896925
# --- 5.003781318664551 сек ---
# Средний доход: -19.70 к эпизоду 24, фрейм 23445, eps 0.988863625
# --- 5.0801615715026855 сек ---
# Средний доход: -19.60 к эпизоду 26, фрейм 25365, eps 0.987951625
# --- 5.429875612258911 сек ---
# Средний доход: -19.90 к эпизоду 28, фрейм 27196, eps 0.9870819
# --- 5.3336501121521 сек ---
# Средний доход: -19.90 к эпизоду 30, фрейм 29000, eps 0.986225
# --- 5.1025378704071045 сек ---
# Net updated!
# Средний доход: -19.90 к эпизоду 32, фрейм 30807, eps 0.985366675
# --- 5.071683406829834 сек ---
# Средний доход: -20.00 к эпизоду 34, фрейм 32572, eps 0.9845283
# --- 4.802172899246216 сек ---
# Средний доход: -20.20 к эпизоду 36, фрейм 34489, eps 0.983617725
# --- 5.286998748779297 сек ---
# Средний доход: -20.20 к эпизоду 38, фрейм 36340, eps 0.9827385
# --- 4.986594915390015 сек ---
# Средний доход: -20.30 к эпизоду 40, фрейм 38276, eps 0.9818189
# --- 5.208804607391357 сек ---
# Net saved!
# Средний доход: -20.10 к эпизоду 42, фрейм 40356, eps 0.9808309
# --- 6.029473066329956 сек ---
# Средний доход: -20.10 к эпизоду 44, фрейм 42036, eps 0.9800329
# --- 4.472742795944214 сек ---
# Средний доход: -20.20 к эпизоду 46, фрейм 43800, eps 0.979195
# --- 4.764503717422485 сек ---
# Net updated!
# Средний доход: -20.20 к эпизоду 48, фрейм 45688, eps 0.9782982
# --- 4.898721694946289 сек ---
# Средний доход: -20.10 к эпизоду 50, фрейм 47541, eps 0.977418025
# --- 4.8290205001831055 сек ---
# Средний доход: -20.40 к эпизоду 52, фрейм 49222, eps 0.97661955
# --- 4.41895604133606 сек ---
# Средний доход: -20.00 к эпизоду 54, фрейм 51223, eps 0.975669075
# --- 5.205963611602783 сек ---
# Средний доход: -19.90 к эпизоду 56, фрейм 52855, eps 0.974893875
# --- 4.211110353469849 сек ---
# Средний доход: -20.10 к эпизоду 58, фрейм 54469, eps 0.974127225
# --- 4.521831750869751 сек ---
# Средний доход: -20.20 к эпизоду 60, фрейм 56135, eps 0.973335875
# --- 4.4203431606292725 сек ---
# Средний доход: -20.10 к эпизоду 62, фрейм 57998, eps 0.97245095
# --- 5.073483228683472 сек ---
# Средний доход: -20.30 к эпизоду 64, фрейм 59975, eps 0.971511875
# --- 5.3123273849487305 сек ---
# Net updated!
# Net saved!
# Средний доход: -20.40 к эпизоду 66, фрейм 61532, eps 0.9707723
# --- 4.0628437995910645 сек ---
# Средний доход: -20.30 к эпизоду 68, фрейм 63219, eps 0.969970975
# --- 4.533734083175659 сек ---
# Средний доход: -20.30 к эпизоду 70, фрейм 64867, eps 0.969188175
# --- 4.579010009765625 сек ---
# Средний доход: -20.40 к эпизоду 72, фрейм 66592, eps 0.9683688
# --- 4.739680767059326 сек ---
# Средний доход: -20.70 к эпизоду 74, фрейм 68455, eps 0.967483875
# --- 5.011377811431885 сек ---
# Средний доход: -20.60 к эпизоду 76, фрейм 70134, eps 0.96668635
# --- 4.574639320373535 сек ---
# Средний доход: -20.60 к эпизоду 78, фрейм 71844, eps 0.9658741
# --- 4.452221632003784 сек ---
# Средний доход: -20.50 к эпизоду 80, фрейм 73681, eps 0.965001525
# --- 4.924165964126587 сек ---
# Net updated!
# Средний доход: -20.30 к эпизоду 82, фрейм 75743, eps 0.964022075
# --- 5.532937049865723 сек ---
# Средний доход: -20.20 к эпизоду 84, фрейм 77374, eps 0.9632473500000001
# --- 4.279891490936279 сек ---
# Средний доход: -20.20 к эпизоду 86, фрейм 79043, eps 0.962454575
# --- 4.415558576583862 сек ---
# Net saved!
# Средний доход: -20.20 к эпизоду 88, фрейм 80672, eps 0.9616808
# --- 4.3770482540130615 сек ---
# Средний доход: -20.40 к эпизоду 90, фрейм 82499, eps 0.960812975
# --- 4.867218732833862 сек ---
# Средний доход: -20.40 к эпизоду 92, фрейм 84499, eps 0.9598629750000001
# --- 5.427887916564941 сек ---
# Средний доход: -20.20 к эпизоду 94, фрейм 86378, eps 0.95897045
# --- 5.036926507949829 сек ---
# Средний доход: -20.30 к эпизоду 96, фрейм 88024, eps 0.9581886
# --- 4.361830711364746 сек ---
# Средний доход: -20.40 к эпизоду 98, фрейм 89548, eps 0.9574647000000001
# --- 4.028664827346802 сек ---
# Net updated!
# Средний доход: -20.00 к эпизоду 100, фрейм 91547, eps 0.956515175
# --- 5.372786521911621 сек ---
# Средний доход: -20.20 к эпизоду 102, фрейм 93313, eps 0.955676325
# --- 4.58256983757019 сек ---
# Средний доход: -20.40 к эпизоду 104, фрейм 94996, eps 0.9548769
# --- 4.48259973526001 сек ---
# Средний доход: -20.30 к эпизоду 106, фрейм 96737, eps 0.954049925
# --- 4.672932863235474 сек ---
# Средний доход: -20.10 к эпизоду 108, фрейм 98421, eps 0.953250025
# --- 4.522629022598267 сек ---
# Средний доход: -20.50 к эпизоду 110, фрейм 99974, eps 0.95251235
# --- 4.215146780014038 сек ---
# Net saved!
# Средний доход: -20.60 к эпизоду 112, фрейм 101605, eps 0.951737625
# --- 4.385703802108765 сек ---
# Средний доход: -20.70 к эпизоду 114, фрейм 103130, eps 0.95101325
# --- 4.1057000160217285 сек ---
# Net updated!
# Средний доход: -20.50 к эпизоду 116, фрейм 105073, eps 0.950090325
# --- 5.113871812820435 сек ---
# Средний доход: -20.60 к эпизоду 118, фрейм 106883, eps 0.949230575
# --- 4.803337812423706 сек ---
# Средний доход: -20.10 к эпизоду 120, фрейм 109035, eps 0.948208375
# --- 5.63203239440918 сек ---
# Средний доход: -20.10 к эпизоду 122, фрейм 110590, eps 0.94746975
# --- 4.003701686859131 сек ---
# Средний доход: -20.10 к эпизоду 124, фрейм 112142, eps 0.94673255
# --- 4.0932297706604 сек ---
# Средний доход: -20.10 к эпизоду 126, фрейм 114104, eps 0.9458006
# --- 5.363659143447876 сек ---
# Средний доход: -20.00 к эпизоду 128, фрейм 115961, eps 0.944918525
# --- 4.684387922286987 сек ---
# Средний доход: -20.30 к эпизоду 130, фрейм 117793, eps 0.944048325
# --- 4.664736986160278 сек ---
# Средний доход: -20.30 к эпизоду 132, фрейм 119347, eps 0.943310175
# --- 4.0553247928619385 сек ---
# Net updated!
# Net saved!
# Средний доход: -20.20 к эпизоду 134, фрейм 121035, eps 0.942508375
# --- 4.526048421859741 сек ---
# Средний доход: -20.20 к эпизоду 136, фрейм 122934, eps 0.94160635
# --- 4.747783422470093 сек ---
# Средний доход: -20.30 к эпизоду 138, фрейм 124630, eps 0.94080075
# --- 4.306292772293091 сек ---
# Средний доход: -20.50 к эпизоду 140, фрейм 126195, eps 0.940057375
# --- 4.101892709732056 сек ---
# Средний доход: -20.50 к эпизоду 142, фрейм 127860, eps 0.9392665
# --- 4.19275975227356 сек ---
# Средний доход: -20.60 к эпизоду 144, фрейм 129476, eps 0.9384989
# --- 4.166417121887207 сек ---
# Средний доход: -20.60 к эпизоду 146, фрейм 131330, eps 0.93761825
# --- 4.886469602584839 сек ---
# Средний доход: -20.60 к эпизоду 148, фрейм 132985, eps 0.936832125
# --- 4.258177757263184 сек ---
# Средний доход: -20.50 к эпизоду 150, фрейм 134697, eps 0.936018925
# --- 4.429663896560669 сек ---
# Net updated!
# Средний доход: -20.40 к эпизоду 152, фрейм 136365, eps 0.935226625
# --- 4.363309621810913 сек ---
# Средний доход: -20.20 к эпизоду 154, фрейм 138252, eps 0.9343303000000001
# --- 4.9838786125183105 сек ---
# Net saved!
# Средний доход: -20.20 к эпизоду 156, фрейм 140305, eps 0.9333551250000001
# --- 5.224577903747559 сек ---
# Средний доход: -20.30 к эпизоду 158, фрейм 141979, eps 0.932559975
# --- 4.3330066204071045 сек ---
# Средний доход: -20.30 к эпизоду 160, фрейм 143662, eps 0.93176055
# --- 4.393471717834473 сек ---
# Средний доход: -20.10 к эпизоду 162, фрейм 145657, eps 0.930812925
# --- 5.194385528564453 сек ---
# Средний доход: -20.20 к эпизоду 164, фрейм 147367, eps 0.930000675
# --- 4.513421058654785 сек ---
# Средний доход: -20.10 к эпизоду 166, фрейм 149323, eps 0.929071575
# --- 5.143860340118408 сек ---
# Net updated!
# Средний доход: -19.80 к эпизоду 168, фрейм 151194, eps 0.92818285
# --- 4.932832717895508 сек ---
# Средний доход: -19.80 к эпизоду 170, фрейм 152933, eps 0.927356825
# --- 4.563186407089233 сек ---
# Средний доход: -19.80 к эпизоду 172, фрейм 154981, eps 0.926384025
# --- 5.476413011550903 сек ---
# Средний доход: -19.60 к эпизоду 174, фрейм 156805, eps 0.925517625
# --- 4.93165397644043 сек ---
# Средний доход: -19.60 к эпизоду 176, фрейм 158788, eps 0.9245757
# --- 5.2295918464660645 сек ---
# Net saved!
# Средний доход: -19.70 к эпизоду 178, фрейм 160782, eps 0.92362855
# --- 5.226443767547607 сек ---
# Средний доход: -19.70 к эпизоду 180, фрейм 162479, eps 0.922822475
# --- 4.4341654777526855 сек ---
# Средний доход: -19.90 к эпизоду 182, фрейм 164241, eps 0.921985525
# --- 4.552675008773804 сек ---
# Net updated!
# Средний доход: -20.10 к эпизоду 184, фрейм 165893, eps 0.921200825
# --- 4.322109699249268 сек ---
# Средний доход: -20.30 к эпизоду 186, фрейм 167769, eps 0.920309725
# --- 4.7531960010528564 сек ---
# Средний доход: -20.30 к эпизоду 188, фрейм 169615, eps 0.919432875
# --- 4.782007455825806 сек ---
# Средний доход: -20.40 к эпизоду 190, фрейм 171276, eps 0.9186439
# --- 4.362056016921997 сек ---
# Средний доход: -20.30 к эпизоду 192, фрейм 173137, eps 0.917759925
# --- 4.7930004596710205 сек ---
# Средний доход: -20.40 к эпизоду 194, фрейм 174876, eps 0.9169339
# --- 4.602552890777588 сек ---
# Средний доход: -20.60 к эпизоду 196, фрейм 176493, eps 0.916165825
# --- 4.182616233825684 сек ---
# Средний доход: -20.70 к эпизоду 198, фрейм 178214, eps 0.91534835
# --- 4.453653812408447 сек ---
# Средний доход: -20.60 к эпизоду 200, фрейм 179933, eps 0.914531825
# --- 4.497621059417725 сек ---
# Net updated!
# Net saved!
# Средний доход: -20.50 к эпизоду 202, фрейм 181919, eps 0.9135884750000001
# --- 5.189393758773804 сек ---
# Средний доход: -20.10 к эпизоду 204, фрейм 184013, eps 0.912593825
# --- 5.34328031539917 сек ---
# Средний доход: -19.90 к эпизоду 206, фрейм 185851, eps 0.911720775
# --- 4.8827972412109375 сек ---
# Средний доход: -19.80 к эпизоду 208, фрейм 187657, eps 0.910862925
# --- 4.886442422866821 сек ---
# Средний доход: -19.80 к эпизоду 210, фрейм 189340, eps 0.9100635
# --- 4.439061641693115 сек ---
# Средний доход: -19.90 к эпизоду 212, фрейм 191098, eps 0.90922845
# --- 4.685631990432739 сек ---
# Средний доход: -20.00 к эпизоду 214, фрейм 193015, eps 0.908317875
# --- 5.064382076263428 сек ---
# Средний доход: -20.20 к эпизоду 216, фрейм 194542, eps 0.90759255
# --- 4.174224853515625 сек ---
# Net updated!
# Средний доход: -20.30 к эпизоду 218, фрейм 196422, eps 0.90669955
# --- 5.100224494934082 сек ---
# Средний доход: -20.30 к эпизоду 220, фрейм 198024, eps 0.9059386
# --- 4.283759832382202 сек ---
# Net saved!
# Средний доход: -20.10 к эпизоду 222, фрейм 200084, eps 0.9049601
# --- 5.580851793289185 сек ---
# Средний доход: -20.40 к эпизоду 224, фрейм 201666, eps 0.9042086500000001
# --- 4.242993354797363 сек ---
# Средний доход: -20.20 к эпизоду 226, фрейм 203377, eps 0.903395925
# --- 4.823988437652588 сек ---
# Средний доход: -20.10 к эпизоду 228, фрейм 205184, eps 0.9025376
# --- 4.706915378570557 сек ---
# Средний доход: -19.80 к эпизоду 230, фрейм 207079, eps 0.901637475
# --- 5.2685487270355225 сек ---
# Средний доход: -20.10 к эпизоду 232, фрейм 208789, eps 0.900825225
# --- 4.715012788772583 сек ---
# Net updated!
# Средний доход: -19.90 к эпизоду 234, фрейм 210667, eps 0.899933175
# --- 6.8057897090911865 сек ---
# Средний доход: -20.00 к эпизоду 236, фрейм 212557, eps 0.899035425
# --- 6.226329803466797 сек ---
# Средний доход: -19.90 к эпизоду 238, фрейм 214442, eps 0.89814005
# --- 5.258275032043457 сек ---
# Средний доход: -20.20 к эпизоду 240, фрейм 216248, eps 0.8972822
# --- 4.776450157165527 сек ---
# Средний доход: -20.20 к эпизоду 242, фрейм 217870, eps 0.89651175
# --- 4.427770614624023 сек ---
# Средний доход: -20.30 к эпизоду 244, фрейм 219492, eps 0.8957413
# --- 4.407168626785278 сек ---
# Net saved!
# Средний доход: -20.20 к эпизоду 246, фрейм 221269, eps 0.894897225
# --- 4.909395217895508 сек ---
# Средний доход: -20.30 к эпизоду 248, фрейм 223211, eps 0.893974775
# --- 5.411455392837524 сек ---
# Net updated!
# Средний доход: -20.30 к эпизоду 250, фрейм 225315, eps 0.892975375
# --- 5.833902359008789 сек ---
# Средний доход: -20.30 к эпизоду 252, фрейм 227069, eps 0.892142225
# --- 4.845863580703735 сек ---
# Средний доход: -20.30 к эпизоду 254, фрейм 228827, eps 0.891307175
# --- 4.804337978363037 сек ---
# Средний доход: -19.90 к эпизоду 256, фрейм 230957, eps 0.890295425
# --- 5.856324195861816 сек ---
# Средний доход: -20.00 к эпизоду 258, фрейм 232752, eps 0.8894428
# --- 4.94481635093689 сек ---
# Средний доход: -20.10 к эпизоду 260, фрейм 234397, eps 0.888661425
# --- 4.754206418991089 сек ---
# Средний доход: -19.90 к эпизоду 262, фрейм 236158, eps 0.8878249500000001
# --- 4.848920822143555 сек ---
# Средний доход: -19.80 к эпизоду 264, фрейм 237887, eps 0.887003675
# --- 4.820372104644775 сек ---
# Средний доход: -20.20 к эпизоду 266, фрейм 239698, eps 0.88614345
# --- 5.106419324874878 сек ---
# Net updated!
# Net saved!
# Средний доход: -19.60 к эпизоду 268, фрейм 242060, eps 0.8850215
# --- 6.727553129196167 сек ---
# Средний доход: -19.50 к эпизоду 270, фрейм 243868, eps 0.8841627
# --- 5.085756540298462 сек ---
# Средний доход: -19.70 к эпизоду 272, фрейм 245570, eps 0.88335425
# --- 4.877909183502197 сек ---
# Средний доход: -19.60 к эпизоду 274, фрейм 247627, eps 0.882377175
# --- 5.76899528503418 сек ---
# Средний доход: -19.80 к эпизоду 276, фрейм 249295, eps 0.881584875
# --- 4.71661376953125 сек ---
# Средний доход: -20.30 к эпизоду 278, фрейм 251149, eps 0.880704225
# --- 5.25879430770874 сек ---
# Средний доход: -20.40 к эпизоду 280, фрейм 252762, eps 0.87993805
# --- 4.523657321929932 сек ---
# Средний доход: -20.40 к эпизоду 282, фрейм 254472, eps 0.8791258
# --- 4.703963756561279 сек ---
# Net updated!
# Средний доход: -20.60 к эпизоду 284, фрейм 256188, eps 0.8783107
# --- 4.611795663833618 сек ---
# Средний доход: -20.50 к эпизоду 286, фрейм 257881, eps 0.877506525
# --- 4.652238607406616 сек ---
# Средний доход: -20.50 к эпизоду 288, фрейм 259688, eps 0.8766482
# --- 4.972720146179199 сек ---
# Net saved!
# Средний доход: -20.40 к эпизоду 290, фрейм 261443, eps 0.875814575
# --- 4.952183246612549 сек ---
# Средний доход: -20.20 к эпизоду 292, фрейм 263376, eps 0.8748964
# --- 5.121960878372192 сек ---
# Средний доход: -20.30 к эпизоду 294, фрейм 265043, eps 0.874104575
# --- 4.443440198898315 сек ---
# Средний доход: -19.80 к эпизоду 296, фрейм 267186, eps 0.8730866500000001
# --- 5.675461292266846 сек ---
# Средний доход: -19.80 к эпизоду 298, фрейм 268985, eps 0.872232125
# --- 4.813351631164551 сек ---
# Net updated!
# Средний доход: -19.80 к эпизоду 300, фрейм 270891, eps 0.871326775
# --- 5.082569122314453 сек ---
# Средний доход: -19.90 к эпизоду 302, фрейм 272689, eps 0.870472725
# --- 4.7832324504852295 сек ---
# Средний доход: -19.80 к эпизоду 304, фрейм 274562, eps 0.86958305
# --- 4.983201742172241 сек ---
# Средний доход: -20.10 к эпизоду 306, фрейм 276671, eps 0.868581275
# --- 5.516509294509888 сек ---
# Средний доход: -20.10 к эпизоду 308, фрейм 278630, eps 0.86765075
# --- 5.225017070770264 сек ---
# Net saved!
# Средний доход: -19.90 к эпизоду 310, фрейм 280425, eps 0.866798125
# --- 4.805085182189941 сек ---
# Средний доход: -20.00 к эпизоду 312, фрейм 282146, eps 0.86598065
# --- 4.507059335708618 сек ---
# Средний доход: -19.80 к эпизоду 314, фрейм 284112, eps 0.8650468
# --- 5.3085222244262695 сек ---
# Net updated!
# Средний доход: -19.90 к эпизоду 316, фрейм 285875, eps 0.864209375
# --- 4.566810131072998 сек ---
# Средний доход: -19.90 к эпизоду 318, фрейм 287713, eps 0.863336325
# --- 4.807445526123047 сек ---
# Средний доход: -19.90 к эпизоду 320, фрейм 289581, eps 0.862449025
# --- 4.763676404953003 сек ---
# Средний доход: -19.80 к эпизоду 322, фрейм 291327, eps 0.861619675
# --- 4.692411661148071 сек ---
# Средний доход: -19.80 к эпизоду 324, фрейм 293279, eps 0.860692475
# --- 5.083128213882446 сек ---
# Средний доход: -20.00 к эпизоду 326, фрейм 294872, eps 0.8599358
# --- 4.182795763015747 сек ---
# Средний доход: -20.00 к эпизоду 328, фрейм 296844, eps 0.8589991
# --- 5.363040924072266 сек ---
# Средний доход: -20.10 к эпизоду 330, фрейм 298544, eps 0.8581916
# --- 4.482525825500488 сек ---
# Net updated!
# Net saved!
# Средний доход: -20.20 к эпизоду 332, фрейм 300263, eps 0.857375075
# --- 4.592427730560303 сек ---
# Средний доход: -20.30 к эпизоду 334, фрейм 302038, eps 0.85653195
# --- 4.673337459564209 сек ---
# Средний доход: -20.20 к эпизоду 336, фрейм 303660, eps 0.8557615000000001
# --- 4.333356857299805 сек ---
# Средний доход: -20.30 к эпизоду 338, фрейм 305567, eps 0.854855675
# --- 5.003416061401367 сек ---
# Средний доход: -20.30 к эпизоду 340, фрейм 307372, eps 0.8539983
# --- 4.763000011444092 сек ---
# Средний доход: -20.20 к эпизоду 342, фрейм 309128, eps 0.8531642
# --- 4.672892093658447 сек ---
# Средний доход: -20.10 к эпизоду 344, фрейм 311205, eps 0.852177625
# --- 5.605630874633789 сек ---
# Средний доход: -20.00 к эпизоду 346, фрейм 313156, eps 0.8512509
# --- 5.123167991638184 сек ---
# Средний доход: -19.90 к эпизоду 348, фрейм 314975, eps 0.850386875
# --- 4.763171672821045 сек ---
# Net updated!
# Средний доход: -19.90 к эпизоду 350, фрейм 316786, eps 0.84952665
# --- 4.822550535202026 сек ---
# Средний доход: -19.70 к эпизоду 352, фрейм 318941, eps 0.8485030250000001
# --- 5.813858509063721 сек ---
# Net saved!
# Средний доход: -19.80 к эпизоду 354, фрейм 320767, eps 0.847635675
# --- 5.073606491088867 сек ---
# Средний доход: -19.80 к эпизоду 356, фрейм 322600, eps 0.846765
# --- 5.003249883651733 сек ---
# Средний доход: -19.30 к эпизоду 358, фрейм 325022, eps 0.8456145500000001
# --- 6.734579086303711 сек ---
# Средний доход: -18.90 к эпизоду 360, фрейм 327170, eps 0.84459425
# --- 5.792693614959717 сек ---
# Средний доход: -19.20 к эпизоду 362, фрейм 328907, eps 0.843769175
# --- 4.75258469581604 сек ---
# Net updated!
# Средний доход: -19.20 к эпизоду 364, фрейм 330762, eps 0.84288805
# --- 5.036542654037476 сек ---
# Средний доход: -19.30 к эпизоду 366, фрейм 332658, eps 0.84198745
# --- 5.130039691925049 сек ---
# Средний доход: -19.90 к эпизоду 368, фрейм 334279, eps 0.841217475
# --- 4.475168228149414 сек ---
# Средний доход: -20.00 к эпизоду 370, фрейм 336539, eps 0.840143975
# --- 6.3565897941589355 сек ---
# Средний доход: -19.90 к эпизоду 372, фрейм 338239, eps 0.8393364750000001
# --- 4.685260534286499 сек ---
# Net saved!
# Средний доход: -19.90 к эпизоду 374, фрейм 340109, eps 0.838448225
# --- 5.185830593109131 сек ---
# Средний доход: -19.90 к эпизоду 376, фрейм 341991, eps 0.837554275
# --- 5.075804710388184 сек ---
# Средний доход: -20.00 к эпизоду 378, фрейм 343604, eps 0.8367881
# --- 4.384845495223999 сек ---
# Net updated!
# Средний доход: -20.40 к эпизоду 380, фрейм 345622, eps 0.83582955
# --- 5.536177396774292 сек ---
# Средний доход: -20.20 к эпизоду 382, фрейм 347772, eps 0.8348083
# --- 5.9277660846710205 сек ---
# Средний доход: -20.30 к эпизоду 384, фрейм 349563, eps 0.833957575
# --- 5.085543394088745 сек ---
# Средний доход: -20.30 к эпизоду 386, фрейм 351285, eps 0.833139625
# --- 4.794680595397949 сек ---
# Средний доход: -20.30 к эпизоду 388, фрейм 352988, eps 0.8323307
# --- 4.712568759918213 сек ---
# Средний доход: -20.00 к эпизоду 390, фрейм 354979, eps 0.831384975
# --- 5.444928884506226 сек ---
# Средний доход: -19.90 к эпизоду 392, фрейм 357312, eps 0.8302768
# --- 6.343363523483276 сек ---
# Средний доход: -19.90 к эпизоду 394, фрейм 359152, eps 0.8294028
# --- 5.015545129776001 сек ---
# Net updated!
# Net saved!
# Средний доход: -19.90 к эпизоду 396, фрейм 361105, eps 0.828475125
# --- 6.1312243938446045 сек ---
# Средний доход: -19.90 к эпизоду 398, фрейм 362661, eps 0.827736025
# --- 4.548424959182739 сек ---
# Средний доход: -20.20 к эпизоду 400, фрейм 364266, eps 0.82697365
# --- 4.479204416275024 сек ---
# Средний доход: -20.40 к эпизоду 402, фрейм 366377, eps 0.825970925
# --- 5.818746566772461 сек ---
# Средний доход: -20.40 к эпизоду 404, фрейм 368060, eps 0.8251715000000001
# --- 4.6630470752716064 сек ---
# Средний доход: -20.30 к эпизоду 406, фрейм 369910, eps 0.82429275
# --- 5.272687196731567 сек ---
# Средний доход: -20.10 к эпизоду 408, фрейм 371640, eps 0.8234710000000001
# --- 4.82390022277832 сек ---
# Средний доход: -19.90 к эпизоду 410, фрейм 373523, eps 0.822576575
# --- 5.1150758266448975 сек ---
# Net updated!
# Средний доход: -19.90 к эпизоду 412, фрейм 375510, eps 0.82163275
# --- 5.61436653137207 сек ---
# Средний доход: -19.70 к эпизоду 414, фрейм 377320, eps 0.820773
# --- 4.974780559539795 сек ---
# Средний доход: -19.90 к эпизоду 416, фрейм 378875, eps 0.820034375
# --- 4.3155436515808105 сек ---
# Net saved!
# Средний доход: -19.70 к эпизоду 418, фрейм 381154, eps 0.81895185
# --- 6.54672646522522 сек ---
# Средний доход: -19.40 к эпизоду 420, фрейм 383201, eps 0.817979525
# --- 5.616004228591919 сек ---
# Средний доход: -19.40 к эпизоду 422, фрейм 385426, eps 0.81692265
# --- 6.027831077575684 сек ---
# Средний доход: -19.70 к эпизоду 424, фрейм 386999, eps 0.816175475
# --- 4.284723281860352 сек ---
# Средний доход: -19.40 к эпизоду 426, фрейм 389066, eps 0.81519365
# --- 5.576754331588745 сек ---
# Net updated!
# Средний доход: -19.80 к эпизоду 428, фрейм 391072, eps 0.8142408
# --- 5.505922794342041 сек ---
# Средний доход: -20.00 к эпизоду 430, фрейм 393043, eps 0.8133045750000001
# --- 5.274731874465942 сек ---
# Средний доход: -20.10 к эпизоду 432, фрейм 394948, eps 0.8123997000000001
# --- 5.18587851524353 сек ---
# Средний доход: -19.90 к эпизоду 434, фрейм 396765, eps 0.811536625
# --- 4.94585919380188 сек ---
# Средний доход: -20.20 к эпизоду 436, фрейм 398371, eps 0.810773775
# --- 4.422037124633789 сек ---
# Net saved!
# Средний доход: -19.90 к эпизоду 438, фрейм 400361, eps 0.809828525
# --- 5.368387460708618 сек ---
# Средний доход: -20.20 к эпизоду 440, фрейм 402152, eps 0.8089778000000001
# --- 4.7948689460754395 сек ---
# Средний доход: -19.90 к эпизоду 442, фрейм 404161, eps 0.8080235250000001
# --- 5.3970091342926025 сек ---
# Net updated!
# Средний доход: -19.90 к эпизоду 444, фрейм 406194, eps 0.8070578500000001
# --- 5.567535638809204 сек ---
# Средний доход: -19.60 к эпизоду 446, фрейм 408035, eps 0.806183375
# --- 5.32889199256897 сек ---
# Средний доход: -19.60 к эпизоду 448, фрейм 409972, eps 0.8052633
# --- 5.146900177001953 сек ---
# Средний доход: -19.50 к эпизоду 450, фрейм 411834, eps 0.80437885
# --- 4.966813325881958 сек ---
# Средний доход: -19.50 к эпизоду 452, фрейм 414247, eps 0.8032326750000001
# --- 6.45189905166626 сек ---
# Средний доход: -19.40 к эпизоду 454, фрейм 416371, eps 0.8022237750000001
# --- 5.809551000595093 сек ---
# Средний доход: -19.10 к эпизоду 456, фрейм 418698, eps 0.80111845
# --- 6.490188360214233 сек ---
# Net updated!
# Net saved!
# Средний доход: -19.20 к эпизоду 458, фрейм 420604, eps 0.8002131
# --- 5.499673843383789 сек ---
# Средний доход: -19.30 к эпизоду 460, фрейм 422330, eps 0.79939325
# --- 4.639395236968994 сек ---
# Средний доход: -19.20 к эпизоду 462, фрейм 424550, eps 0.79833875
# --- 6.18358588218689 сек ---
# Средний доход: -19.40 к эпизоду 464, фрейм 426593, eps 0.797368325
# --- 5.407487869262695 сек ---
# Средний доход: -19.90 к эпизоду 466, фрейм 428414, eps 0.79650335
# --- 4.837019205093384 сек ---
# Средний доход: -19.60 к эпизоду 468, фрейм 430509, eps 0.7955082250000001
# --- 5.6075990200042725 сек ---
# Средний доход: -19.50 к эпизоду 470, фрейм 432425, eps 0.794598125
# --- 5.16797947883606 сек ---
# Средний доход: -19.50 к эпизоду 472, фрейм 434751, eps 0.793493275
# --- 6.17027735710144 сек ---
# Net updated!
# Средний доход: -19.40 к эпизоду 474, фрейм 436858, eps 0.79249245
# --- 5.585515022277832 сек ---
# Средний доход: -19.10 к эпизоду 476, фрейм 439054, eps 0.79144935
# --- 5.989706039428711 сек ---
# Net saved!
# Средний доход: -19.40 к эпизоду 478, фрейм 440857, eps 0.790592925
# --- 5.008468151092529 сек ---
# Средний доход: -19.50 к эпизоду 480, фрейм 442616, eps 0.7897574
# --- 4.6881422996521 сек ---
# Средний доход: -19.90 к эпизоду 482, фрейм 444544, eps 0.7888416
# --- 5.205284357070923 сек ---
# Средний доход: -19.80 к эпизоду 484, фрейм 446381, eps 0.787969025
# --- 4.9088828563690186 сек ---
# Средний доход: -19.80 к эпизоду 486, фрейм 448523, eps 0.786951575
# --- 5.790155410766602 сек ---
# Net updated!
# Средний доход: -20.00 к эпизоду 488, фрейм 450169, eps 0.786169725
# --- 4.621630668640137 сек ---
# Средний доход: -19.80 к эпизоду 490, фрейм 452166, eps 0.78522115
# --- 5.414963483810425 сек ---
# Средний доход: -20.00 к эпизоду 492, фрейм 454039, eps 0.784331475
# --- 5.148059129714966 сек ---
# Средний доход: -20.00 к эпизоду 494, фрейм 455913, eps 0.7834413250000001
# --- 5.199952840805054 сек ---
# Средний доход: -20.00 к эпизоду 496, фрейм 458406, eps 0.78225715
# --- 6.841092586517334 сек ---
# Net saved!
# Средний доход: -19.60 к эпизоду 498, фрейм 460626, eps 0.78120265
# --- 6.2306177616119385 сек ---
# Средний доход: -19.70 к эпизоду 500, фрейм 462675, eps 0.780229375
# --- 5.668742656707764 сек ---
# Средний доход: -19.40 к эпизоду 502, фрейм 464647, eps 0.779292675
# --- 5.54709267616272 сек ---
# Net updated!
# Средний доход: -19.30 к эпизоду 504, фрейм 466780, eps 0.7782795
# --- 6.090957164764404 сек ---
# Средний доход: -19.30 к эпизоду 506, фрейм 468688, eps 0.7773732
# --- 5.5919342041015625 сек ---
# Средний доход: -19.10 к эпизоду 508, фрейм 471145, eps 0.7762061250000001
# --- 6.987692356109619 сек ---
# Средний доход: -18.70 к эпизоду 510, фрейм 473392, eps 0.7751388
# --- 6.342103958129883 сек ---
# Средний доход: -18.40 к эпизоду 512, фрейм 475505, eps 0.774135125
# --- 5.931685924530029 сек ---
# Средний доход: -18.50 к эпизоду 514, фрейм 477423, eps 0.773224075
# --- 5.296900272369385 сек ---
# Средний доход: -18.60 к эпизоду 516, фрейм 479604, eps 0.7721881
# --- 6.07567572593689 сек ---
# Net updated!
# Net saved!
# Средний доход: -19.00 к эпизоду 518, фрейм 481412, eps 0.7713293
# --- 5.005361557006836 сек ---
# Средний доход: -19.10 к эпизоду 520, фрейм 483594, eps 0.77029285
# --- 5.905743360519409 сек ---
# Средний доход: -19.30 к эпизоду 522, фрейм 485663, eps 0.769310075
# --- 5.623612642288208 сек ---
# Средний доход: -19.40 к эпизоду 524, фрейм 487808, eps 0.7682912000000001
# --- 5.877542734146118 сек ---
# Средний доход: -19.40 к эпизоду 526, фрейм 489938, eps 0.76727945
# --- 5.696935176849365 сек ---
# Средний доход: -19.00 к эпизоду 528, фрейм 492353, eps 0.7661323250000001
# --- 6.57970118522644 сек ---
# Средний доход: -19.00 к эпизоду 530, фрейм 494497, eps 0.7651139250000001
# --- 5.756102561950684 сек ---
# Net updated!
# Средний доход: -18.90 к эпизоду 532, фрейм 496658, eps 0.76408745
# --- 5.826564311981201 сек ---
# Средний доход: -18.50 к эпизоду 534, фрейм 498948, eps 0.7629997000000001
# --- 6.14766788482666 сек ---
# Net saved!
# Средний доход: -18.30 к эпизоду 536, фрейм 501040, eps 0.762006
# --- 5.7665793895721436 сек ---
# Средний доход: -18.90 к эпизоду 538, фрейм 502642, eps 0.7612450500000001
# --- 4.334625005722046 сек ---
# Средний доход: -19.00 к эпизоду 540, фрейм 504581, eps 0.7603240250000001
# --- 5.180186986923218 сек ---
# Средний доход: -19.30 к эпизоду 542, фрейм 506466, eps 0.75942865
# --- 5.008495330810547 сек ---
# Средний доход: -19.70 к эпизоду 544, фрейм 508651, eps 0.7583907750000001
# --- 5.859515905380249 сек ---
# Net updated!
# Средний доход: -19.90 к эпизоду 546, фрейм 510590, eps 0.75746975
# --- 5.2850501537323 сек ---
# Средний доход: -19.50 к эпизоду 548, фрейм 512679, eps 0.7564774750000001
# --- 5.685885906219482 сек ---
# Средний доход: -19.70 к эпизоду 550, фрейм 514502, eps 0.75561155
# --- 5.0900938510894775 сек ---
# Средний доход: -18.70 к эпизоду 552, фрейм 517301, eps 0.754282025
# --- 7.574578046798706 сек ---
# Средний доход: -18.10 к эпизоду 554, фрейм 519698, eps 0.75314345
# --- 6.711979150772095 сек ---
# Net saved!
# Средний доход: -17.90 к эпизоду 556, фрейм 521906, eps 0.7520946500000001
# --- 6.191720724105835 сек ---
# Средний доход: -17.40 к эпизоду 558, фрейм 524814, eps 0.7507133500000001
# --- 7.994771718978882 сек ---
# Net updated!
# Средний доход: -17.40 к эпизоду 560, фрейм 526811, eps 0.749764775
# --- 5.3853349685668945 сек ---
# Средний доход: -18.20 к эпизоду 562, фрейм 529042, eps 0.7487050500000001
# --- 6.266537666320801 сек ---
# Средний доход: -18.70 к эпизоду 564, фрейм 530993, eps 0.7477783250000001
# --- 5.42611837387085 сек ---
# Средний доход: -18.70 к эпизоду 566, фрейм 533315, eps 0.746675375
# --- 6.358497619628906 сек ---
# Средний доход: -19.30 к эпизоду 568, фрейм 535191, eps 0.7457842750000001
# --- 5.22424840927124 сек ---
# Средний доход: -19.20 к эпизоду 570, фрейм 537213, eps 0.7448238250000001
# --- 5.675282001495361 сек ---
# Средний доход: -19.50 к эпизоду 572, фрейм 538835, eps 0.744053375
# --- 4.478187322616577 сек ---
# Net updated!
# Net saved!
# Средний доход: -19.50 к эпизоду 574, фрейм 540830, eps 0.74310575
# --- 5.690669298171997 сек ---
# Средний доход: -19.00 к эпизоду 576, фрейм 543415, eps 0.741877875
# --- 7.203131437301636 сек ---
# Средний доход: -18.80 к эпизоду 578, фрейм 545472, eps 0.7409008
# --- 5.829970836639404 сек ---
# Средний доход: -18.20 к эпизоду 580, фрейм 548054, eps 0.73967435
# --- 7.403533935546875 сек ---
# Средний доход: -18.10 к эпизоду 582, фрейм 550092, eps 0.7387063
# --- 5.8504297733306885 сек ---
# Средний доход: -18.00 к эпизоду 584, фрейм 552432, eps 0.7375948000000001
# --- 6.573789119720459 сек ---
# Net updated!
# Средний доход: -18.30 к эпизоду 586, фрейм 555227, eps 0.736267175
# --- 7.941785573959351 сек ---
# Средний доход: -18.70 к эпизоду 588, фрейм 557149, eps 0.735354225
# --- 5.457698822021484 сек ---
# Средний доход: -19.10 к эпизоду 590, фрейм 559565, eps 0.734206625
# --- 6.60266637802124 сек ---
# Net saved!
# Средний доход: -18.70 к эпизоду 592, фрейм 561881, eps 0.733106525
# --- 6.446119546890259 сек ---
# Средний доход: -18.30 к эпизоду 594, фрейм 564325, eps 0.731945625
# --- 8.094967365264893 сек ---
# Средний доход: -18.60 к эпизоду 596, фрейм 566540, eps 0.7308935000000001
# --- 6.2512712478637695 сек ---
# Средний доход: -18.60 к эпизоду 598, фрейм 568293, eps 0.730060825
# --- 4.880094289779663 сек ---
# Net updated!
# Средний доход: -18.50 к эпизоду 600, фрейм 570900, eps 0.7288225
# --- 7.3948071002960205 сек ---
# Средний доход: -18.80 к эпизоду 602, фрейм 572855, eps 0.727893875
# --- 5.471222162246704 сек ---
# Средний доход: -19.30 к эпизоду 604, фрейм 574947, eps 0.726900175
# --- 5.757060766220093 сек ---
# Средний доход: -19.60 к эпизоду 606, фрейм 577093, eps 0.725880825
# --- 5.911437034606934 сек ---
# Средний доход: -19.30 к эпизоду 608, фрейм 579333, eps 0.724816825
# --- 6.27397084236145 сек ---
# Net saved!
# Средний доход: -19.50 к эпизоду 610, фрейм 581573, eps 0.723752825
# --- 6.21750283241272 сек ---
# Средний доход: -19.40 к эпизоду 612, фрейм 583911, eps 0.722642275
# --- 6.398452520370483 сек ---
# Net updated!
# Средний доход: -19.30 к эпизоду 614, фрейм 585908, eps 0.7216937000000001
# --- 5.599910736083984 сек ---
# Средний доход: -19.00 к эпизоду 616, фрейм 587904, eps 0.7207456000000001
# --- 5.635997295379639 сек ---
# Средний доход: -19.00 к эпизоду 618, фрейм 590150, eps 0.71967875
# --- 6.505033254623413 сек ---
# Средний доход: -19.10 к эпизоду 620, фрейм 592231, eps 0.718690275
# --- 5.988158941268921 сек ---
# Средний доход: -19.20 к эпизоду 622, фрейм 594121, eps 0.717792525
# --- 5.343708276748657 сек ---
# Средний доход: -19.30 к эпизоду 624, фрейм 596009, eps 0.7168957250000001
# --- 5.43354868888855 сек ---
# Средний доход: -19.40 к эпизоду 626, фрейм 597900, eps 0.7159975000000001
# --- 5.334316730499268 сек ---
# Средний доход: -19.40 к эпизоду 628, фрейм 599930, eps 0.7150332500000001
# --- 5.733883380889893 сек ---
# Net updated!
# Net saved!
# Средний доход: -19.30 к эпизоду 630, фрейм 602196, eps 0.7139569
# --- 6.394084930419922 сек ---
# Средний доход: -19.20 к эпизоду 632, фрейм 604349, eps 0.712934225
# --- 5.9841296672821045 сек ---
# Средний доход: -19.40 к эпизоду 634, фрейм 606340, eps 0.7119885
# --- 5.513148546218872 сек ---
# Средний доход: -19.10 к эпизоду 636, фрейм 608570, eps 0.71092925
# --- 6.084155797958374 сек ---
# Средний доход: -19.20 к эпизоду 638, фрейм 610537, eps 0.709994925
# --- 5.454059839248657 сек ---
# Средний доход: -19.20 к эпизоду 640, фрейм 612793, eps 0.708923325
# --- 6.184179782867432 сек ---
# Средний доход: -19.40 к эпизоду 642, фрейм 614707, eps 0.708014175
# --- 5.383160352706909 сек ---
# Net updated!
# Средний доход: -19.30 к эпизоду 644, фрейм 616766, eps 0.70703615
# --- 5.74162745475769 сек ---
# Средний доход: -19.80 к эпизоду 646, фрейм 618661, eps 0.7061360250000001
# --- 5.279348134994507 сек ---
# Net saved!
# Средний доход: -19.60 к эпизоду 648, фрейм 620805, eps 0.705117625
# --- 6.07373309135437 сек ---
# Средний доход: -19.80 к эпизоду 650, фрейм 622713, eps 0.704211325
# --- 5.4717628955841064 сек ---
# Средний доход: -19.80 к эпизоду 652, фрейм 624636, eps 0.7032979
# --- 5.51726770401001 сек ---
# Средний доход: -19.50 к эпизоду 654, фрейм 627049, eps 0.702151725
# --- 6.8378989696502686 сек ---
# Средний доход: -19.10 к эпизоду 656, фрейм 629266, eps 0.70109865
# --- 6.24813437461853 сек ---
# Net updated!
# Средний доход: -19.20 к эпизоду 658, фрейм 631523, eps 0.7000265750000001
# --- 6.2972633838653564 сек ---
# Средний доход: -19.20 к эпизоду 660, фрейм 633309, eps 0.699178225
# --- 4.845412969589233 сек ---
# Средний доход: -19.30 к эпизоду 662, фрейм 635151, eps 0.698303275
# --- 5.078521013259888 сек ---
# Средний доход: -19.30 к эпизоду 664, фрейм 637450, eps 0.6972112500000001
# --- 6.400688886642456 сек ---
# Net saved!
# Средний доход: -19.00 к эпизоду 666, фрейм 640068, eps 0.6959677
# --- 7.276688814163208 сек ---
# Средний доход: -18.90 к эпизоду 668, фрейм 642278, eps 0.69491795
# --- 6.084572076797485 сек ---
# Средний доход: -18.60 к эпизоду 670, фрейм 644534, eps 0.6938463500000001
# --- 6.536041021347046 сек ---
# Net updated!
# Средний доход: -18.30 к эпизоду 672, фрейм 646707, eps 0.6928141750000001
# --- 6.045314788818359 сек ---
# Средний доход: -18.00 к эпизоду 674, фрейм 649428, eps 0.6915217
# --- 7.644199848175049 сек ---
# Средний доход: -18.40 к эпизоду 676, фрейм 651809, eps 0.6903907250000001
# --- 6.692318916320801 сек ---
# Средний доход: -18.40 к эпизоду 678, фрейм 654003, eps 0.689348575
# --- 6.32160496711731 сек ---
# Средний доход: -18.70 к эпизоду 680, фрейм 655891, eps 0.6884517750000001
# --- 5.302534580230713 сек ---
# Средний доход: -18.40 к эпизоду 682, фрейм 658097, eps 0.687403925
# --- 6.22916316986084 сек ---
# Net updated!
# Net saved!
# Средний доход: -18.70 к эпизоду 684, фрейм 660508, eps 0.6862587
# --- 6.727515697479248 сек ---
# Средний доход: -18.80 к эпизоду 686, фрейм 662584, eps 0.6852726
# --- 5.880157470703125 сек ---
# Средний доход: -18.80 к эпизоду 688, фрейм 665203, eps 0.684028575
# --- 7.271652936935425 сек ---
# Средний доход: -18.40 к эпизоду 690, фрейм 667566, eps 0.68290615
# --- 6.783904790878296 сек ---
# Средний доход: -18.40 к эпизоду 692, фрейм 670209, eps 0.681650725
# --- 7.352337121963501 сек ---
# Средний доход: -18.20 к эпизоду 694, фрейм 672773, eps 0.680432825
# --- 7.050097227096558 сек ---
# Net updated!
# Средний доход: -17.30 к эпизоду 696, фрейм 675593, eps 0.679093325
# --- 7.779556035995483 сек ---
# Средний доход: -17.50 к эпизоду 698, фрейм 677592, eps 0.6781438
# --- 5.997929811477661 сек ---
# Средний доход: -17.90 к эпизоду 700, фрейм 679642, eps 0.67717005
# --- 5.9078145027160645 сек ---
# Net saved!
# Средний доход: -18.40 к эпизоду 702, фрейм 681791, eps 0.676149275
# --- 6.043007850646973 сек ---
# Средний доход: -18.70 к эпизоду 704, фрейм 683726, eps 0.67523015
# --- 5.430137872695923 сек ---
# Средний доход: -19.50 к эпизоду 706, фрейм 685812, eps 0.6742393
# --- 5.858336925506592 сек ---
# Средний доход: -19.00 к эпизоду 708, фрейм 688444, eps 0.6729891
# --- 7.5051281452178955 сек ---
# Net updated!
# Средний доход: -18.70 к эпизоду 710, фрейм 690681, eps 0.671926525
# --- 6.281296968460083 сек ---
# Средний доход: -18.10 к эпизоду 712, фрейм 693197, eps 0.670731425
# --- 6.821929454803467 сек ---
# Средний доход: -18.10 к эпизоду 714, фрейм 695307, eps 0.6697291750000001
# --- 5.9678356647491455 сек ---
# Средний доход: -18.40 к эпизоду 716, фрейм 697499, eps 0.6686879750000001
# --- 6.1361987590789795 сек ---
# Средний доход: -18.80 к эпизоду 718, фрейм 699603, eps 0.667688575
# --- 6.071901082992554 сек ---
# Net saved!
# Средний доход: -18.90 к эпизоду 720, фрейм 701662, eps 0.66671055
# --- 5.820432662963867 сек ---
# Средний доход: -19.20 к эпизоду 722, фрейм 703858, eps 0.66566745
# --- 6.221234321594238 сек ---
# Net updated!
# Средний доход: -19.40 к эпизоду 724, фрейм 706161, eps 0.664573525
# --- 6.609983205795288 сек ---
# Средний доход: -19.10 к эпизоду 726, фрейм 708459, eps 0.6634819750000001
# --- 6.668438673019409 сек ---
# Средний доход: -18.90 к эпизоду 728, фрейм 710760, eps 0.6623890000000001
# --- 6.639770269393921 сек ---
# Средний доход: -19.00 к эпизоду 730, фрейм 712987, eps 0.661331175
# --- 6.451597690582275 сек ---
# Средний доход: -18.70 к эпизоду 732, фрейм 715590, eps 0.6600947500000001
# --- 7.579776763916016 сек ---
# Средний доход: -18.40 к эпизоду 734, фрейм 717754, eps 0.6590668500000001
# --- 6.267021894454956 сек ---
# Net updated!
# Net saved!
# Средний доход: -17.90 к эпизоду 736, фрейм 720369, eps 0.657824725
# --- 7.581742525100708 сек ---
# Средний доход: -18.10 к эпизоду 738, фрейм 722684, eps 0.6567251000000001
# --- 6.579039096832275 сек ---
# Средний доход: -18.10 к эпизоду 740, фрейм 724898, eps 0.6556734500000001
# --- 6.346994400024414 сек ---
# Средний доход: -18.60 к эпизоду 742, фрейм 726921, eps 0.6547125250000001
# --- 6.040883541107178 сек ---
# Средний доход: -18.50 к эпизоду 744, фрейм 729563, eps 0.653457575
# --- 7.692389249801636 сек ---
# Средний доход: -19.30 к эпизоду 746, фрейм 731575, eps 0.652501875
# --- 6.190650463104248 сек ---
# Средний доход: -18.80 к эпизоду 748, фрейм 734122, eps 0.65129205
# --- 7.592514991760254 сек ---
# Net updated!
# Средний доход: -18.20 к эпизоду 750, фрейм 736856, eps 0.6499934
# --- 7.892174959182739 сек ---
# Средний доход: -18.00 к эпизоду 752, фрейм 739080, eps 0.6489370000000001
# --- 6.424465656280518 сек ---
# Net saved!
# Средний доход: -17.60 к эпизоду 754, фрейм 741724, eps 0.6476811
# --- 8.064021587371826 сек ---
# Средний доход: -17.20 к эпизоду 756, фрейм 744052, eps 0.6465753000000001
# --- 6.856795072555542 сек ---
# Средний доход: -17.40 к эпизоду 758, фрейм 746515, eps 0.6454053750000001
# --- 7.1050498485565186 сек ---
# Средний доход: -17.40 к эпизоду 760, фрейм 749122, eps 0.6441670500000001
# --- 7.5660316944122314 сек ---
# Net updated!
# Средний доход: -17.30 к эпизоду 762, фрейм 751662, eps 0.64296055
# --- 7.507433891296387 сек ---
# Средний доход: -17.90 к эпизоду 764, фрейм 753929, eps 0.641883725
# --- 6.575788259506226 сек ---
# Средний доход: -18.10 к эпизоду 766, фрейм 755936, eps 0.6409304
# --- 5.906179904937744 сек ---
# Средний доход: -18.20 к эпизоду 768, фрейм 758249, eps 0.6398317250000001
# --- 6.755985975265503 сек ---
# Net saved!
# Средний доход: -18.60 к эпизоду 770, фрейм 760609, eps 0.638710725
# --- 7.043062686920166 сек ---
# Средний доход: -18.70 к эпизоду 772, фрейм 762965, eps 0.637591625
# --- 6.741851329803467 сек ---
# Net updated!
# Средний доход: -18.70 к эпизоду 774, фрейм 765128, eps 0.6365642
# --- 6.186119794845581 сек ---
# Средний доход: -18.30 к эпизоду 776, фрейм 767514, eps 0.6354308500000001
# --- 6.677339315414429 сек ---
# Средний доход: -18.30 к эпизоду 778, фрейм 769927, eps 0.634284675
# --- 7.015570878982544 сек ---
# Средний доход: -18.30 к эпизоду 780, фрейм 772368, eps 0.6331252
# --- 7.125460624694824 сек ---
# Средний доход: -18.30 к эпизоду 782, фрейм 774632, eps 0.6320498000000001
# --- 6.436316251754761 сек ---
# Средний доход: -18.20 к эпизоду 784, фрейм 777155, eps 0.630851375
# --- 7.185515642166138 сек ---
# Средний доход: -18.50 к эпизоду 786, фрейм 779402, eps 0.62978405
# --- 6.456666469573975 сек ---
# Net updated!
# Net saved!
# Средний доход: -18.40 к эпизоду 788, фрейм 781948, eps 0.6285747
# --- 7.352379083633423 сек ---
# Средний доход: -18.30 к эпизоду 790, фрейм 784281, eps 0.627466525
# --- 7.061606407165527 сек ---
# Средний доход: -18.50 к эпизоду 792, фрейм 786246, eps 0.62653315
# --- 6.1319358348846436 сек ---
# Средний доход: -18.60 к эпизоду 794, фрейм 788443, eps 0.625489575
# --- 6.750223159790039 сек ---
# Средний доход: -18.30 к эпизоду 796, фрейм 791055, eps 0.624248875
# --- 8.103672504425049 сек ---
# Средний доход: -18.30 к эпизоду 798, фрейм 793538, eps 0.62306945
# --- 7.277496576309204 сек ---
# Net updated!
# Средний доход: -18.30 к эпизоду 800, фрейм 796172, eps 0.6218183
# --- 9.322668552398682 сек ---
# Средний доход: -18.10 к эпизоду 802, фрейм 798610, eps 0.62066025
# --- 7.019851446151733 сек ---
# Net saved!
# Средний доход: -17.70 к эпизоду 804, фрейм 801257, eps 0.619402925
# --- 7.6095263957977295 сек ---
# Средний доход: -17.80 к эпизоду 806, фрейм 803498, eps 0.61833845
# --- 6.561991453170776 сек ---
# Средний доход: -18.00 к эпизоду 808, фрейм 805629, eps 0.617326225
# --- 6.361810684204102 сек ---
# Средний доход: -18.00 к эпизоду 810, фрейм 808137, eps 0.6161349250000001
# --- 7.265416383743286 сек ---
# Net updated!
# Средний доход: -18.00 к эпизоду 812, фрейм 810573, eps 0.614977825
# --- 7.184962034225464 сек ---
# Средний доход: -18.00 к эпизоду 814, фрейм 813117, eps 0.6137694250000001
# --- 7.386336088180542 сек ---
# Средний доход: -17.50 к эпизоду 816, фрейм 816228, eps 0.6122917000000001
# --- 8.997503995895386 сек ---
# Средний доход: -17.60 к эпизоду 818, фрейм 818675, eps 0.611129375
# --- 7.105745315551758 сек ---
# Net saved!
# Средний доход: -17.60 к эпизоду 820, фрейм 821129, eps 0.6099637250000001
# --- 7.086955785751343 сек ---
# Средний доход: -17.70 к эпизоду 822, фрейм 823485, eps 0.608844625
# --- 6.899972438812256 сек ---
# Net updated!
# Средний доход: -18.20 к эпизоду 824, фрейм 825818, eps 0.60773645
# --- 6.791444301605225 сек ---
# Средний доход: -19.00 к эпизоду 826, фрейм 828170, eps 0.60661925
# --- 6.645132064819336 сек ---
# Средний доход: -18.80 к эпизоду 828, фрейм 830617, eps 0.605456925
# --- 7.115299463272095 сек ---
# Средний доход: -18.70 к эпизоду 830, фрейм 833225, eps 0.604218125
# --- 7.555580377578735 сек ---
# Средний доход: -17.90 к эпизоду 832, фрейм 836311, eps 0.6027522750000001
# --- 9.006566047668457 сек ---
# Средний доход: -17.70 к эпизоду 834, фрейм 838708, eps 0.6016137
# --- 7.014864206314087 сек ---
# Net updated!
# Net saved!
# Средний доход: -16.80 к эпизоду 836, фрейм 841683, eps 0.600200575
# --- 8.785523653030396 сек ---
# Средний доход: -17.00 к эпизоду 838, фрейм 844068, eps 0.5990677
# --- 7.090255498886108 сек ---
# Средний доход: -17.30 к эпизоду 840, фрейм 846448, eps 0.5979372000000001
# --- 6.898317098617554 сек ---
# Средний доход: -17.90 к эпизоду 842, фрейм 849104, eps 0.5966756
# --- 7.759912014007568 сек ---
# Средний доход: -17.80 к эпизоду 844, фрейм 851508, eps 0.5955337
# --- 6.918146371841431 сек ---
# Средний доход: -18.40 к эпизоду 846, фрейм 854011, eps 0.594344775
# --- 7.1976611614227295 сек ---
# Net updated!
# Средний доход: -17.80 к эпизоду 848, фрейм 856682, eps 0.5930760500000001
# --- 8.175981760025024 сек ---
# Средний доход: -17.50 к эпизоду 850, фрейм 859078, eps 0.59193795
# --- 7.176224708557129 сек ---
# Net saved!
# Средний доход: -17.60 к эпизоду 852, фрейм 861248, eps 0.5909072
# --- 6.656307935714722 сек ---
# Средний доход: -17.90 к эпизоду 854, фрейм 863160, eps 0.589999
# --- 5.698955535888672 сек ---
# Средний доход: -18.20 к эпизоду 856, фрейм 865526, eps 0.58887515
# --- 7.1495044231414795 сек ---
# Средний доход: -18.60 к эпизоду 858, фрейм 868162, eps 0.58762305
# --- 7.823864221572876 сек ---
# Net updated!
# Средний доход: -18.80 к эпизоду 860, фрейм 870404, eps 0.5865581
# --- 6.6236231327056885 сек ---
# Средний доход: -18.30 к эпизоду 862, фрейм 873303, eps 0.585181075
# --- 8.564948081970215 сек ---
# Средний доход: -18.40 к эпизоду 864, фрейм 875486, eps 0.58414415
# --- 6.5334718227386475 сек ---
# Средний доход: -18.50 к эпизоду 866, фрейм 877653, eps 0.583114825
# --- 6.463483810424805 сек ---
# Средний доход: -18.80 к эпизоду 868, фрейм 879592, eps 0.5821938
# --- 5.753544569015503 сек ---
# Net saved!
# Средний доход: -18.90 к эпизоду 870, фрейм 881678, eps 0.58120295
# --- 6.218135833740234 сек ---
# Средний доход: -18.80 к эпизоду 872, фрейм 884615, eps 0.579807875
# --- 8.68023419380188 сек ---
# Net updated!
# Средний доход: -18.60 к эпизоду 874, фрейм 886854, eps 0.57874435
# --- 6.7095420360565186 сек ---
# Средний доход: -17.70 к эпизоду 876, фрейм 889737, eps 0.577374925
# --- 8.425756216049194 сек ---
# Средний доход: -17.30 к эпизоду 878, фрейм 892057, eps 0.576272925
# --- 6.978437185287476 сек ---
# Средний доход: -17.30 к эпизоду 880, фрейм 894248, eps 0.5752322000000001
# --- 6.458328485488892 сек ---
# Средний доход: -17.40 к эпизоду 882, фрейм 897159, eps 0.573849475
# --- 9.204689025878906 сек ---
# Средний доход: -17.00 к эпизоду 884, фрейм 899628, eps 0.5726767
# --- 8.362436294555664 сек ---
# Net updated!
# Net saved!
# Средний доход: -17.70 к эпизоду 886, фрейм 901767, eps 0.5716606750000001
# --- 6.605297088623047 сек ---
# Средний доход: -17.50 к эпизоду 888, фрейм 904205, eps 0.570502625
# --- 7.436524391174316 сек ---
# Средний доход: -17.50 к эпизоду 890, фрейм 906728, eps 0.5693042
# --- 8.51859164237976 сек ---
# Средний доход: -17.80 к эпизоду 892, фрейм 909268, eps 0.5680977
# --- 8.376292943954468 сек ---
# Средний доход: -17.70 к эпизоду 894, фрейм 911735, eps 0.566925875
# --- 7.659987449645996 сек ---
# Средний доход: -17.30 к эпизоду 896, фрейм 914363, eps 0.565677575
# --- 7.893138647079468 сек ---
# Net updated!
# Средний доход: -17.90 к эпизоду 898, фрейм 916505, eps 0.5646601250000001
# --- 6.43692421913147 сек ---
# Средний доход: -17.60 к эпизоду 900, фрейм 918976, eps 0.5634864
# --- 7.626740455627441 сек ---
# Net saved!
# Средний доход: -17.60 к эпизоду 902, фрейм 921709, eps 0.5621882250000001
# --- 8.184128522872925 сек ---
# Средний доход: -17.80 к эпизоду 904, фрейм 924209, eps 0.561000725
# --- 7.489109754562378 сек ---
# Средний доход: -18.10 к эпизоду 906, фрейм 926439, eps 0.559941475
# --- 6.596879243850708 сек ---
# Средний доход: -17.80 к эпизоду 908, фрейм 928928, eps 0.5587592000000001
# --- 7.457149267196655 сек ---
# Net updated!
# Средний доход: -18.10 к эпизоду 910, фрейм 931495, eps 0.557539875
# --- 7.706474304199219 сек ---
# Средний доход: -18.10 к эпизоду 912, фрейм 934111, eps 0.556297275
# --- 7.975473403930664 сек ---
# Средний доход: -17.70 к эпизоду 914, фрейм 936750, eps 0.5550437500000001
# --- 7.982911109924316 сек ---
# Средний доход: -17.50 к эпизоду 916, фрейм 939060, eps 0.5539465000000001
# --- 6.911368131637573 сек ---
# Net saved!
# Средний доход: -17.10 к эпизоду 918, фрейм 942141, eps 0.5524830250000001
# --- 9.187955141067505 сек ---
# Средний доход: -16.70 к эпизоду 920, фрейм 944906, eps 0.5511696500000001
# --- 8.187726736068726 сек ---
# Net updated!
# Средний доход: -16.90 к эпизоду 922, фрейм 947281, eps 0.550041525
# --- 7.275041818618774 сек ---
# Средний доход: -17.10 к эпизоду 924, фрейм 949864, eps 0.5488146
# --- 7.564770460128784 сек ---
# Средний доход: -17.30 к эпизоду 926, фрейм 952078, eps 0.5477629500000001
# --- 6.524778604507446 сек ---
# Средний доход: -17.50 к эпизоду 928, фрейм 955070, eps 0.5463417500000001
# --- 8.836113214492798 сек ---
# Средний доход: -17.60 к эпизоду 930, фрейм 957373, eps 0.545247825
# --- 6.954669952392578 сек ---
# Средний доход: -17.70 к эпизоду 932, фрейм 959711, eps 0.544137275
# --- 6.944324016571045 сек ---
# Net updated!
# Net saved!
# Средний доход: -17.80 к эпизоду 934, фрейм 962778, eps 0.54268045
# --- 9.33773922920227 сек ---
# Средний доход: -17.20 к эпизоду 936, фрейм 965839, eps 0.541226475
# --- 9.076566457748413 сек ---
# Средний доход: -17.50 к эпизоду 938, фрейм 968383, eps 0.5400180750000001
# --- 7.545202016830444 сек ---
# Средний доход: -18.10 к эпизоду 940, фрейм 970274, eps 0.5391198500000001
# --- 5.613989353179932 сек ---
# Средний доход: -17.50 к эпизоду 942, фрейм 973038, eps 0.53780695
# --- 8.125719785690308 сек ---
# Net updated!
# Средний доход: -17.40 к эпизоду 944, фрейм 975549, eps 0.5366142250000001
# --- 7.604063987731934 сек ---
# Средний доход: -17.80 к эпизоду 946, фрейм 977870, eps 0.5355117500000001
# --- 7.0440590381622314 сек ---
# Средний доход: -18.10 к эпизоду 948, фрейм 979763, eps 0.534612575
# --- 5.673739910125732 сек ---
# Net saved!
# Средний доход: -17.70 к эпизоду 950, фрейм 982141, eps 0.533483025
# --- 7.144431114196777 сек ---
# Средний доход: -17.90 к эпизоду 952, фрейм 984876, eps 0.5321839
# --- 8.285125494003296 сек ---
# Средний доход: -17.90 к эпизоду 954, фрейм 987792, eps 0.5307988000000001
# --- 8.62056303024292 сек ---
# ...
# --- 12.703072786331177 сек ---
# Средний доход: -0.40 к эпизоду 1616, фрейм 2051724, eps 0.05
# --- 17.286603689193726 сек ---
# Net updated!
# Средний доход: -2.00 к эпизоду 1618, фрейм 2055466, eps 0.05
# --- 12.59254240989685 сек ---
# Средний доход: -2.50 к эпизоду 1620, фрейм 2059690, eps 0.05
# --- 14.248646974563599 сек ---
# Net saved!
# Средний доход: -2.90 к эпизоду 1622, фрейм 2065005, eps 0.05
# --- 18.072054386138916 сек ---
# Средний доход: -4.50 к эпизоду 1624, фрейм 2069468, eps 0.05
# --- 15.03052830696106 сек ---
# Net updated!
# Средний доход: -3.80 к эпизоду 1626, фрейм 2074555, eps 0.05
# --- 17.18259882926941 сек ---
# Средний доход: -2.90 к эпизоду 1628, фрейм 2079355, eps 0.05
# --- 16.0008442401886 сек ---
# Net saved!
# Средний доход: -2.70 к эпизоду 1630, фрейм 2084203, eps 0.05
# --- 16.574519157409668 сек ---
# Net updated!
# Средний доход: -3.00 к эпизоду 1632, фрейм 2088823, eps 0.05
# --- 15.644420146942139 сек ---
# Средний доход: -2.20 к эпизоду 1634, фрейм 2093878, eps 0.05
# --- 17.04983115196228 сек ---
# Средний доход: -2.70 к эпизоду 1636, фрейм 2098438, eps 0.05
# --- 15.366724252700806 сек ---
# Net updated!
# Net saved!
# Средний доход: -1.00 к эпизоду 1638, фрейм 2102959, eps 0.05
# --- 15.397763013839722 сек ---
# Средний доход: -1.00 к эпизоду 1640, фрейм 2107690, eps 0.05
# --- 15.908441305160522 сек ---
# Средний доход: 0.60 к эпизоду 1642, фрейм 2112882, eps 0.05
# --- 17.4455463886261 сек ---
# Net updated!
# Средний доход: -0.10 к эпизоду 1644, фрейм 2117269, eps 0.05
# --- 15.698201417922974 сек ---
# Net saved!
# Средний доход: -0.60 к эпизоду 1646, фрейм 2121767, eps 0.05
# --- 16.518104553222656 сек ---
# Средний доход: -3.30 к эпизоду 1648, фрейм 2125553, eps 0.05
# --- 12.726532936096191 сек ---
# Net updated!
# Средний доход: -1.40 к эпизоду 1650, фрейм 2130860, eps 0.05
# --- 17.940614461898804 сек ---
# Средний доход: -4.30 к эпизоду 1652, фрейм 2134610, eps 0.05
# --- 12.663059711456299 сек ---
# Средний доход: -4.50 к эпизоду 1654, фрейм 2139145, eps 0.05
# --- 15.398032903671265 сек ---
# Net saved!
# Средний доход: -3.40 к эпизоду 1656, фрейм 2143482, eps 0.05
# --- 14.505082368850708 сек ---
# Net updated!
# Средний доход: -1.40 к эпизоду 1658, фрейм 2148158, eps 0.05
# --- 15.44935917854309 сек ---
# Средний доход: -5.80 к эпизоду 1660, фрейм 2150360, eps 0.05
# --- 7.333962440490723 сек ---
# Средний доход: -3.30 к эпизоду 1662, фрейм 2155412, eps 0.05
# --- 16.854228973388672 сек ---
# Средний доход: -1.90 к эпизоду 1664, фрейм 2159985, eps 0.05
# --- 15.306309700012207 сек ---
# Net updated!
# Net saved!
# Средний доход: -1.70 к эпизоду 1666, фрейм 2164577, eps 0.05
# --- 15.18249225616455 сек ---
# Средний доход: 0.70 к эпизоду 1668, фрейм 2168812, eps 0.05
# --- 14.143344402313232 сек ---
# Средний доход: 2.80 к эпизоду 1670, фрейм 2172781, eps 0.05
# --- 13.263256311416626 сек ---
# Net updated!
# Средний доход: 0.30 к эпизоду 1672, фрейм 2176958, eps 0.05
# --- 13.980964183807373 сек ---
# Net saved!
# Средний доход: -0.50 к эпизоду 1674, фрейм 2181744, eps 0.05
# --- 15.768013954162598 сек ---
# Средний доход: -3.20 к эпизоду 1676, фрейм 2185530, eps 0.05
# --- 12.664438486099243 сек ---
# Средний доход: -6.90 к эпизоду 1678, фрейм 2189658, eps 0.05
# --- 13.915805339813232 сек ---
# Net updated!
# Средний доход: -6.60 к эпизоду 1680, фрейм 2194257, eps 0.05
# --- 15.390146255493164 сек ---
# Средний доход: -7.10 к эпизоду 1682, фрейм 2197971, eps 0.05
# --- 12.249276161193848 сек ---
# Net saved!
# Средний доход: -9.50 к эпизоду 1684, фрейм 2201149, eps 0.05
# --- 11.118465185165405 сек ---
# Net updated!
# Средний доход: -9.10 к эпизоду 1686, фрейм 2205496, eps 0.05
# --- 14.842588186264038 сек ---
# Средний доход: -8.10 к эпизоду 1688, фрейм 2210486, eps 0.05
# --- 16.319563627243042 сек ---
# Средний доход: -7.70 к эпизоду 1690, фрейм 2215688, eps 0.05
# --- 17.062049865722656 сек ---
# Средний доход: -7.50 к эпизоду 1692, фрейм 2219713, eps 0.05
# --- 13.093518018722534 сек ---
# Net updated!
# Net saved!
# Средний доход: -4.40 к эпизоду 1694, фрейм 2225311, eps 0.05
# --- 18.52450656890869 сек ---
# Средний доход: -3.20 к эпизоду 1696, фрейм 2229405, eps 0.05
# --- 13.525707006454468 сек ---
# Средний доход: -6.10 к эпизоду 1698, фрейм 2231962, eps 0.05
# --- 8.547388553619385 сек ---
# Net updated!
# Средний доход: -7.10 к эпизоду 1700, фрейм 2236225, eps 0.05
# --- 14.47271203994751 сек ---
# Net saved!
# Средний доход: -5.00 к эпизоду 1702, фрейм 2241311, eps 0.05
# --- 16.760176181793213 сек ---
# Средний доход: -5.50 к эпизоду 1704, фрейм 2245425, eps 0.05
# --- 13.475028276443481 сек ---
# Средний доход: -7.50 к эпизоду 1706, фрейм 2248770, eps 0.05
# --- 10.98841118812561 сек ---
# Net updated!
# Средний доход: -5.90 к эпизоду 1708, фрейм 2252347, eps 0.05
# --- 11.908058643341064 сек ---
# Средний доход: -2.80 к эпизоду 1710, фрейм 2257381, eps 0.05
# --- 16.479118585586548 сек ---
# Net saved!
# Средний доход: -4.40 к эпизоду 1712, фрейм 2261506, eps 0.05
# --- 13.696065902709961 сек ---
# Net updated!
# Средний доход: -4.00 к эпизоду 1714, фрейм 2266355, eps 0.05
# --- 16.149155616760254 сек ---
# Средний доход: -4.20 к эпизоду 1716, фрейм 2269878, eps 0.05
# --- 11.542003870010376 сек ---
# Средний доход: -6.40 к эпизоду 1718, фрейм 2271697, eps 0.05
# --- 6.046915769577026 сек ---
# Средний доход: -6.50 к эпизоду 1720, фрейм 2276391, eps 0.05
# --- 15.350560426712036 сек ---
# Net updated!
# Net saved!
# Средний доход: -6.00 к эпизоду 1722, фрейм 2281355, eps 0.05
# --- 16.37304925918579 сек ---
# Средний доход: -7.80 к эпизоду 1724, фрейм 2285603, eps 0.05
# --- 13.92777943611145 сек ---
# Средний доход: -7.40 к эпизоду 1726, фрейм 2289523, eps 0.05
# --- 12.759565114974976 сек ---
# Средний доход: -5.20 к эпизоду 1728, фрейм 2294075, eps 0.05
# --- 14.773649215698242 сек ---
# Net updated!
# Средний доход: -8.50 к эпизоду 1730, фрейм 2298146, eps 0.05
# --- 13.514134645462036 сек ---
# Net saved!
# Средний доход: -11.40 к эпизоду 1732, фрейм 2300072, eps 0.05
# --- 6.465123176574707 сек ---
# Средний доход: -9.70 к эпизоду 1734, фрейм 2304321, eps 0.05
# --- 14.354200839996338 сек ---
# Средний доход: -7.10 к эпизоду 1736, фрейм 2309204, eps 0.05
# --- 16.601495027542114 сек ---
# Net updated!
# Средний доход: -4.60 к эпизоду 1738, фрейм 2313785, eps 0.05
# --- 17.001178979873657 сек ---
# Средний доход: -3.30 к эпизоду 1740, фрейм 2319254, eps 0.05
# --- 19.284996509552002 сек ---
# Net saved!
# Средний доход: 1.60 к эпизоду 1742, фрейм 2324082, eps 0.05
# --- 16.207552433013916 сек ---
# Net updated!
# Средний доход: -1.00 к эпизоду 1744, фрейм 2327541, eps 0.05
# --- 11.626553535461426 сек ---
# Средний доход: -1.10 к эпизоду 1746, фрейм 2331672, eps 0.05
# --- 13.930042743682861 сек ---
# Средний доход: -3.60 к эпизоду 1748, фрейм 2336070, eps 0.05
# --- 14.705064296722412 сек ---
# Net updated!
# Net saved!
# Средний доход: -3.60 к эпизоду 1750, фрейм 2340973, eps 0.05
# --- 16.310892343521118 сек ---
# Средний доход: -3.40 к эпизоду 1752, фрейм 2346046, eps 0.05
# --- 16.51186442375183 сек ---
# Средний доход: 0.70 к эпизоду 1754, фрейм 2350914, eps 0.05
# --- 15.987105369567871 сек ---
# Net updated!
# Средний доход: -1.20 к эпизоду 1756, фрейм 2355250, eps 0.05
# --- 14.291468143463135 сек ---
# Средний доход: -0.90 к эпизоду 1758, фрейм 2359466, eps 0.05
# --- 13.791550397872925 сек ---
# Net saved!
# Средний доход: -0.60 к эпизоду 1760, фрейм 2364544, eps 0.05
# --- 16.716013193130493 сек ---
# Средний доход: -3.50 к эпизоду 1762, фрейм 2369287, eps 0.05
# --- 15.58868670463562 сек ---
# Net updated!
# Средний доход: -6.80 к эпизоду 1764, фрейм 2373413, eps 0.05
# --- 13.441542148590088 сек ---
# Средний доход: -7.00 к эпизоду 1766, фрейм 2377257, eps 0.05
# --- 12.803114175796509 сек ---
# Net saved!
# Средний доход: -7.90 к эпизоду 1768, фрейм 2381251, eps 0.05
# --- 13.186485290527344 сек ---
# Средний доход: -10.00 к эпизоду 1770, фрейм 2384618, eps 0.05
# --- 11.083542823791504 сек ---
# Net updated!
# Средний доход: -11.10 к эпизоду 1772, фрейм 2387610, eps 0.05
# --- 9.79369306564331 сек ---
# Средний доход: -10.70 к эпизоду 1774, фрейм 2392424, eps 0.05
# --- 15.891035079956055 сек ---
# Средний доход: -10.60 к эпизоду 1776, фрейм 2396651, eps 0.05
# --- 13.792812824249268 сек ---
# Net updated!
# Net saved!
# Средний доход: -8.00 к эпизоду 1778, фрейм 2401715, eps 0.05
# --- 18.085472106933594 сек ---
# Средний доход: -7.10 к эпизоду 1780, фрейм 2406125, eps 0.05
# --- 14.48448920249939 сек ---
# Средний доход: -4.50 к эпизоду 1782, фрейм 2410206, eps 0.05
# --- 13.491552829742432 сек ---
# Средний доход: -5.00 к эпизоду 1784, фрейм 2414581, eps 0.05
# --- 14.635508060455322 сек ---
# Net updated!
# Средний доход: -5.30 к эпизоду 1786, фрейм 2418721, eps 0.05
# --- 13.79714846611023 сек ---
# Net saved!
# Средний доход: -5.60 к эпизоду 1788, фрейм 2424140, eps 0.05
# --- 18.41256022453308 сек ---
# Средний доход: -6.50 к эпизоду 1790, фрейм 2427528, eps 0.05
# --- 11.556439399719238 сек ---
# Net updated!
# Средний доход: -7.80 к эпизоду 1792, фрейм 2431816, eps 0.05
# --- 14.67504334449768 сек ---
# Средний доход: -6.40 к эпизоду 1794, фрейм 2436214, eps 0.05
# --- 15.025175094604492 сек ---
# Net saved!
# Средний доход: -5.60 к эпизоду 1796, фрейм 2440812, eps 0.05
# --- 15.722963333129883 сек ---
# Net updated!
# Средний доход: -4.30 к эпизоду 1798, фрейм 2445733, eps 0.05
# --- 16.39830780029297 сек ---
# Средний доход: -0.90 к эпизоду 1800, фрейм 2450920, eps 0.05
# --- 17.33472180366516 сек ---
# Средний доход: -0.50 к эпизоду 1802, фрейм 2453837, eps 0.05
# --- 9.815881490707397 сек ---
# Средний доход: 2.00 к эпизоду 1804, фрейм 2458044, eps 0.05
# --- 14.126699447631836 сек ---
# Net updated!
# Net saved!
# Средний доход: -0.20 к эпизоду 1806, фрейм 2460309, eps 0.05
# --- 7.6830973625183105 сек ---
# Средний доход: -3.20 к эпизоду 1808, фрейм 2464175, eps 0.05
# --- 12.636111497879028 сек ---
# Средний доход: -7.20 к эпизоду 1810, фрейм 2466841, eps 0.05
# --- 8.634353637695312 сек ---
# Средний доход: -8.60 к эпизоду 1812, фрейм 2470079, eps 0.05
# --- 10.675334930419922 сек ---
# Средний доход: -13.10 к эпизоду 1814, фрейм 2473482, eps 0.05
# --- 11.084044456481934 сек ---
# Net updated!
# Средний доход: -11.70 к эпизоду 1816, фрейм 2477207, eps 0.05
# --- 12.348731279373169 сек ---
# Net saved!
# Средний доход: -12.80 к эпизоду 1818, фрейм 2480182, eps 0.05
# --- 9.786334753036499 сек ---
# Средний доход: -9.60 к эпизоду 1820, фрейм 2485576, eps 0.05
# --- 19.3215172290802 сек ---
# Net updated!
# Средний доход: -8.10 к эпизоду 1822, фрейм 2490675, eps 0.05
# --- 18.3007333278656 сек ---
# Средний доход: -5.60 к эпизоду 1824, фрейм 2493997, eps 0.05
# --- 10.950603008270264 сек ---
# Средний доход: -0.70 к эпизоду 1826, фрейм 2497972, eps 0.05
# --- 13.004985332489014 сек ---
# Net saved!
# Средний доход: 4.10 к эпизоду 1828, фрейм 2502738, eps 0.05
# --- 15.620601654052734 сек ---
# Net updated!
# Средний доход: 2.20 к эпизоду 1830, фрейм 2506549, eps 0.05
# --- 12.541367769241333 сек ---
# Средний доход: 1.40 к эпизоду 1832, фрейм 2510469, eps 0.05
# --- 12.810523748397827 сек ---
# Средний доход: -0.50 к эпизоду 1834, фрейм 2514264, eps 0.05
# --- 12.368991136550903 сек ---
# Средний доход: -2.10 к эпизоду 1836, фрейм 2519313, eps 0.05
# --- 16.582336902618408 сек ---
# Net updated!
# Net saved!
# Средний доход: -5.60 к эпизоду 1838, фрейм 2523626, eps 0.05
# --- 14.190688610076904 сек ---
# Средний доход: -6.60 к эпизоду 1840, фрейм 2526667, eps 0.05
# --- 10.35803747177124 сек ---
# Средний доход: -4.20 к эпизоду 1842, фрейм 2532030, eps 0.05
# --- 17.774894952774048 сек ---
# Net updated!
# Средний доход: -5.10 к эпизоду 1844, фрейм 2535150, eps 0.05
# --- 10.257313966751099 сек ---
# Средний доход: -7.20 к эпизоду 1846, фрейм 2538717, eps 0.05
# --- 11.827176570892334 сек ---
# Net saved!
# Средний доход: -7.30 к эпизоду 1848, фрейм 2541967, eps 0.05
# --- 11.001333236694336 сек ---
# Средний доход: -6.80 к эпизоду 1850, фрейм 2545407, eps 0.05
# --- 12.075528621673584 сек ---
# Средний доход: -9.10 к эпизоду 1852, фрейм 2549034, eps 0.05
# --- 12.36684513092041 сек ---
# Net updated!
# Средний доход: -10.00 к эпизоду 1854, фрейм 2551267, eps 0.05
# --- 7.564042568206787 сек ---
# Средний доход: -10.50 к эпизоду 1856, фрейм 2555381, eps 0.05
# --- 13.774602174758911 сек ---
# Средний доход: -9.50 к эпизоду 1858, фрейм 2558627, eps 0.05
# --- 10.713495969772339 сек ---
# Net saved!
# Средний доход: -9.70 к эпизоду 1860, фрейм 2561554, eps 0.05
# --- 9.761624097824097 сек ---
# Net updated!
# Средний доход: -9.80 к эпизоду 1862, фрейм 2565056, eps 0.05
# --- 11.604067087173462 сек ---
# Средний доход: -5.00 к эпизоду 1864, фрейм 2569672, eps 0.05
# --- 15.706037759780884 сек ---
# Средний доход: -6.10 к эпизоду 1866, фрейм 2573257, eps 0.05
# --- 12.184792041778564 сек ---
# Средний доход: -8.10 к эпизоду 1868, фрейм 2576341, eps 0.05
# --- 11.287498235702515 сек ---
# Средний доход: -7.00 к эпизоду 1870, фрейм 2579519, eps 0.05
# --- 12.555544137954712 сек ---
# Net updated!
# Net saved!
# Средний доход: -6.50 к эпизоду 1872, фрейм 2584080, eps 0.05
# --- 15.8767728805542 сек ---
# Средний доход: -9.50 к эпизоду 1874, фрейм 2588347, eps 0.05
# --- 14.807478189468384 сек ---
# Средний доход: -7.30 к эпизоду 1876, фрейм 2592384, eps 0.05
# --- 13.69692087173462 сек ---
# Net updated!
# Средний доход: -3.30 к эпизоду 1878, фрейм 2597118, eps 0.05
# --- 16.766481161117554 сек ---
# Net saved!
# Средний доход: -1.70 к эпизоду 1880, фрейм 2601008, eps 0.05
# --- 14.27304744720459 сек ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 DQN_control(env, agent, num_episodes = 2000)
#
# Cell In[54], line 18, in DQN_control(env, agent, num_episodes)
#      16 while True:
#      17     action = agent.get_action(state)
# ---> 18     next_state, reward, terminated, truncated, _ = env.step(action)
#      19     agent.update(state, action, reward, next_state, terminated)
#      20     state = next_state
#
# File C:\ProgramData\Anaconda3\lib\site-packages\gymnasium\wrappers\common.py:513, in RecordEpisodeStatistics.step(self, action)
#     509 def step(
#     510     self, action: ActType
#     511 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     512     """Steps through the environment, recording the episode statistics."""
# --> 513     obs, reward, terminated, truncated, info = super().step(action)
#     515     self.episode_returns += reward
#     516     self.episode_lengths += 1
#
# File C:\ProgramData\Anaconda3\lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\gymnasium\wrappers\stateful_observation.py:416, in FrameStackObservation.step(self, action)
#     405 def step(
#     406     self, action: WrapperActType
#     407 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     408     """Steps through the environment, appending the observation to the frame buffer.
#     409
#     410     Args:
#    (...)
#     414         Stacked observations, reward, terminated, truncated, and info from the environment
#     415     """
# --> 416     obs, reward, terminated, truncated, info = self.env.step(action)
#     417     self.obs_queue.append(obs)
#     419     updated_obs = deepcopy(
#     420         concatenate(self.env.observation_space, self.obs_queue, self.stacked_obs)
#     421     )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\gymnasium\wrappers\atari_preprocessing.py:184, in AtariPreprocessing.step(self, action)
#     182         else:
#     183             self.ale.getScreenRGB(self.obs_buffer[0])
# --> 184 return self._get_obs(), total_reward, terminated, truncated, info
#
# File C:\ProgramData\Anaconda3\lib\site-packages\gymnasium\wrappers\atari_preprocessing.py:219, in AtariPreprocessing._get_obs(self)
#     215     np.maximum(self.obs_buffer[0], self.obs_buffer[1], out=self.obs_buffer[0])
#     217 import cv2
# --> 219 obs = cv2.resize(
#     220     self.obs_buffer[0],
#     221     self.screen_size,
#     222     interpolation=cv2.INTER_AREA,
#     223 )
#     225 if self.scale_obs:
#     226     obs = np.asarray(obs, dtype=np.float32) / 255.0
#
# KeyboardInterrupt:

# %%
env = make_env("ALE/Pong-v5")
env = gym.wrappers.RecordEpisodeStatistics(env)
agent.alpha = 0.0001
BATCH_SIZE = 32
DQN_control(env, agent, num_episodes = 200)
# Out:
# Средний доход: 4.00 к эпизоду 0, фрейм 2604514, eps 0.05
# --- 8.649867057800293 сек ---
# Средний доход: -1.00 к эпизоду 2, фрейм 2608551, eps 0.05
# --- 14.36881422996521 сек ---
# Net updated!
# Средний доход: -3.80 к эпизоду 4, фрейм 2612413, eps 0.05
# --- 13.655808448791504 сек ---
# Средний доход: -7.71 к эпизоду 6, фрейм 2614516, eps 0.05
# --- 7.437786817550659 сек ---
# Средний доход: -6.00 к эпизоду 8, фрейм 2618368, eps 0.05
# --- 13.709545850753784 сек ---
# Net saved!
# Средний доход: -6.90 к эпизоду 10, фрейм 2621292, eps 0.05
# --- 10.431851625442505 сек ---
# Средний доход: -8.30 к эпизоду 12, фрейм 2624783, eps 0.05
# --- 12.3392813205719 сек ---
# Net updated!
# Средний доход: -6.20 к эпизоду 14, фрейм 2629252, eps 0.05
# --- 15.795490026473999 сек ---
# Средний доход: -5.80 к эпизоду 16, фрейм 2631859, eps 0.05
# --- 9.23294734954834 сек ---
# Средний доход: -8.50 к эпизоду 18, фрейм 2634979, eps 0.05
# --- 11.137505531311035 сек ---
# Средний доход: -7.80 к эпизоду 20, фрейм 2639362, eps 0.05
# --- 15.531833410263062 сек ---
# Net updated!
# Net saved!
# Средний доход: -7.10 к эпизоду 22, фрейм 2643565, eps 0.05
# --- 14.785643339157104 сек ---
# Средний доход: -7.90 к эпизоду 24, фрейм 2648220, eps 0.05
# --- 16.588691234588623 сек ---
# Средний доход: -8.00 к эпизоду 26, фрейм 2650799, eps 0.05
# --- 9.166378736495972 сек ---
# Средний доход: -8.20 к эпизоду 28, фрейм 2653703, eps 0.05
# --- 10.213385581970215 сек ---
# Net updated!
# Средний доход: -7.70 к эпизоду 30, фрейм 2658299, eps 0.05
# --- 16.308362245559692 сек ---
# Net saved!
# Средний доход: -8.80 к эпизоду 32, фрейм 2662200, eps 0.05
# --- 13.671885013580322 сек ---
# Средний доход: -7.80 к эпизоду 34, фрейм 2667297, eps 0.05
# --- 17.89882254600525 сек ---
# Net updated!
# Средний доход: -3.70 к эпизоду 36, фрейм 2671878, eps 0.05
# --- 16.306827783584595 сек ---
# Средний доход: -1.10 к эпизоду 38, фрейм 2675786, eps 0.05
# --- 13.84786057472229 сек ---
# Net saved!
# Средний доход: -2.10 к эпизоду 40, фрейм 2680555, eps 0.05
# --- 16.963548183441162 сек ---
# Средний доход: -2.70 к эпизоду 42, фрейм 2683212, eps 0.05
# --- 9.400567054748535 сек ---
# Net updated!
# Средний доход: -4.80 к эпизоду 44, фрейм 2687392, eps 0.05
# --- 14.815010786056519 сек ---
# Средний доход: -7.00 к эпизоду 46, фрейм 2691700, eps 0.05
# --- 15.296627044677734 сек ---
# Средний доход: -9.10 к эпизоду 48, фрейм 2695482, eps 0.05
# --- 13.275302171707153 сек ---
# Средний доход: -8.50 к эпизоду 50, фрейм 2699474, eps 0.05
# --- 14.513077735900879 сек ---
# Net updated!
# Net saved!
# Средний доход: -5.70 к эпизоду 52, фрейм 2703728, eps 0.05
# --- 15.115072250366211 сек ---
# Средний доход: -4.50 к эпизоду 54, фрейм 2708678, eps 0.05
# --- 17.628384351730347 сек ---
# Средний доход: -1.60 к эпизоду 56, фрейм 2713815, eps 0.05
# --- 18.434226274490356 сек ---
# Net updated!
# Средний доход: 2.80 к эпизоду 58, фрейм 2718770, eps 0.05
# --- 17.71860122680664 сек ---
# Net saved!
# Средний доход: 5.20 к эпизоду 60, фрейм 2723638, eps 0.05
# --- 17.246897220611572 сек ---
# Средний доход: 3.20 к эпизоду 62, фрейм 2727536, eps 0.05
# --- 13.768032789230347 сек ---
# Net updated!
# Средний доход: 1.40 к эпизоду 64, фрейм 2731443, eps 0.05
# --- 13.845229625701904 сек ---
# Средний доход: -2.00 к эпизоду 66, фрейм 2735567, eps 0.05
# --- 14.823440313339233 сек ---
# Net saved!
# Средний доход: -3.90 к эпизоду 68, фрейм 2741346, eps 0.05
# --- 20.67760467529297 сек ---
# Net updated!
# Средний доход: -6.00 к эпизоду 70, фрейм 2746585, eps 0.05
# --- 18.530412435531616 сек ---
# Средний доход: -5.20 к эпизоду 72, фрейм 2750964, eps 0.05
# --- 15.41606855392456 сек ---
# Средний доход: -3.80 к эпизоду 74, фрейм 2755484, eps 0.05
# --- 16.091623306274414 сек ---
# Net updated!
# Net saved!
# Средний доход: -0.60 к эпизоду 76, фрейм 2760292, eps 0.05
# --- 16.999436616897583 сек ---
# Средний доход: 0.00 к эпизоду 78, фрейм 2765261, eps 0.05
# --- 17.622299432754517 сек ---
# Средний доход: 2.30 к эпизоду 80, фрейм 2769536, eps 0.05
# --- 15.151073217391968 сек ---
# Средний доход: 4.70 к эпизоду 82, фрейм 2774555, eps 0.05
# --- 17.81436014175415 сек ---
# Net updated!
# Средний доход: 3.50 к эпизоду 84, фрейм 2778556, eps 0.05
# --- 14.30440354347229 сек ---
# Net saved!
# Средний доход: 2.80 к эпизоду 86, фрейм 2782027, eps 0.05
# --- 12.388461112976074 сек ---
# Средний доход: 2.10 к эпизоду 88, фрейм 2787227, eps 0.05
# --- 18.374311685562134 сек ---
# Net updated!
# Средний доход: 0.40 к эпизоду 90, фрейм 2791838, eps 0.05
# --- 16.263906955718994 сек ---
# Средний доход: -1.50 к эпизоду 92, фрейм 2796364, eps 0.05
# --- 16.08254909515381 сек ---
# Net saved!
# Средний доход: -0.50 к эпизоду 94, фрейм 2801370, eps 0.05
# --- 17.718093156814575 сек ---
# Net updated!
# Средний доход: 0.00 к эпизоду 96, фрейм 2806306, eps 0.05
# --- 17.455519676208496 сек ---
# Средний доход: 0.80 к эпизоду 98, фрейм 2810353, eps 0.05
# --- 14.252299070358276 сек ---
# Средний доход: 0.90 к эпизоду 100, фрейм 2814443, eps 0.05
# --- 14.556757926940918 сек ---
# Средний доход: 0.70 к эпизоду 102, фрейм 2817925, eps 0.05
# --- 12.310445547103882 сек ---
# Net updated!
# Net saved!
# Средний доход: 2.10 к эпизоду 104, фрейм 2823031, eps 0.05
# --- 18.085172414779663 сек ---
# Средний доход: 0.20 к эпизоду 106, фрейм 2827713, eps 0.05
# --- 16.549858331680298 сек ---
# Средний доход: -1.70 к эпизоду 108, фрейм 2831820, eps 0.05
# --- 14.530053853988647 сек ---
# Net updated!
# Средний доход: 0.30 к эпизоду 110, фрейм 2835991, eps 0.05
# --- 14.716714859008789 сек ---
# Net saved!
# Средний доход: 1.90 к эпизоду 112, фрейм 2840989, eps 0.05
# --- 17.70043444633484 сек ---
# Средний доход: 0.40 к эпизоду 114, фрейм 2846054, eps 0.05
# --- 17.80651044845581 сек ---
# Средний доход: -1.50 к эпизоду 116, фрейм 2849315, eps 0.05
# --- 11.564795017242432 сек ---
# Net updated!
# Средний доход: -3.60 к эпизоду 118, фрейм 2851778, eps 0.05
# --- 8.735720872879028 сек ---
# Средний доход: -5.60 к эпизоду 120, фрейм 2856363, eps 0.05
# --- 16.118908166885376 сек ---
# Средний доход: -5.80 к эпизоду 122, фрейм 2859948, eps 0.05
# --- 12.728661060333252 сек ---
# Net saved!
# Средний доход: -5.20 к эпизоду 124, фрейм 2863583, eps 0.05
# --- 12.904611587524414 сек ---
# Net updated!
# Средний доход: -3.00 к эпизоду 126, фрейм 2867830, eps 0.05
# --- 14.987730264663696 сек ---
# Средний доход: 1.10 к эпизоду 128, фрейм 2871992, eps 0.05
# --- 14.629331111907959 сек ---
# Средний доход: 2.50 к эпизоду 130, фрейм 2876648, eps 0.05
# --- 16.487629652023315 сек ---
# Net updated!
# Net saved!
# Средний доход: 2.70 к эпизоду 132, фрейм 2881411, eps 0.05
# --- 16.730740308761597 сек ---
# Средний доход: 0.80 к эпизоду 134, фрейм 2885062, eps 0.05
# --- 12.924821853637695 сек ---
# Средний доход: 0.10 к эпизоду 136, фрейм 2888762, eps 0.05
# --- 13.131187915802002 сек ---
# Средний доход: -2.50 к эпизоду 138, фрейм 2892913, eps 0.05
# --- 14.66206407546997 сек ---
# Net updated!
# Средний доход: -5.30 к эпизоду 140, фрейм 2897031, eps 0.05
# --- 14.651425123214722 сек ---
# Net saved!
# Средний доход: -3.70 к эпизоду 142, фрейм 2901218, eps 0.05
# --- 14.79480266571045 сек ---
# Средний доход: -0.80 к эпизоду 144, фрейм 2905978, eps 0.05
# --- 16.822535276412964 сек ---
# Net updated!
# Средний доход: -1.20 к эпизоду 146, фрейм 2910285, eps 0.05
# --- 15.216995239257812 сек ---
# Средний доход: -0.30 к эпизоду 148, фрейм 2913471, eps 0.05
# --- 11.223901271820068 сек ---
# Средний доход: -1.90 к эпизоду 150, фрейм 2917182, eps 0.05
# --- 13.150668382644653 сек ---
# Net saved!
# Средний доход: -1.70 к эпизоду 152, фрейм 2921816, eps 0.05
# --- 16.435702323913574 сек ---
# Net updated!
# Средний доход: -1.70 к эпизоду 154, фрейм 2926331, eps 0.05
# --- 16.056187868118286 сек ---
# Средний доход: -1.30 к эпизоду 156, фрейм 2930934, eps 0.05
# --- 16.28513789176941 сек ---
# Средний доход: -0.70 к эпизоду 158, фрейм 2935764, eps 0.05
# --- 16.99592113494873 сек ---
# Net updated!
# Net saved!
# Средний доход: 1.80 к эпизоду 160, фрейм 2940971, eps 0.05
# --- 18.362785816192627 сек ---
# Средний доход: -2.10 к эпизоду 162, фрейм 2944825, eps 0.05
# --- 13.587379932403564 сек ---
# Средний доход: -3.30 к эпизоду 164, фрейм 2948885, eps 0.05
# --- 14.400267601013184 сек ---
# Средний доход: -1.50 к эпизоду 166, фрейм 2953955, eps 0.05
# --- 17.913136959075928 сек ---
# Net updated!
# Средний доход: -3.20 к эпизоду 168, фрейм 2957876, eps 0.05
# --- 14.410935640335083 сек ---
# Net saved!
# Средний доход: -5.20 к эпизоду 170, фрейм 2961679, eps 0.05
# --- 13.312368869781494 сек ---
# Средний доход: -4.90 к эпизоду 172, фрейм 2965734, eps 0.05
# --- 14.286810874938965 сек ---
# Net updated!
# Средний доход: -5.10 к эпизоду 174, фрейм 2970763, eps 0.05
# --- 17.910003900527954 сек ---
# Средний доход: -6.70 к эпизоду 176, фрейм 2974217, eps 0.05
# --- 12.25087308883667 сек ---
# Средний доход: -5.60 к эпизоду 178, фрейм 2978436, eps 0.05
# --- 14.9386727809906 сек ---
# Net saved!
# Средний доход: -4.10 к эпизоду 180, фрейм 2982989, eps 0.05
# --- 16.270812511444092 сек ---
# Net updated!
# Средний доход: -3.60 к эпизоду 182, фрейм 2987747, eps 0.05
# --- 17.114094972610474 сек ---
# Средний доход: -5.90 к эпизоду 184, фрейм 2990721, eps 0.05
# --- 10.659768104553223 сек ---
# Средний доход: -5.00 к эпизоду 186, фрейм 2994979, eps 0.05
# --- 15.270617008209229 сек ---
# Средний доход: -7.00 к эпизоду 188, фрейм 2998120, eps 0.05
# --- 11.156462669372559 сек ---
# Net updated!
# Net saved!
# Средний доход: -9.00 к эпизоду 190, фрейм 3002034, eps 0.05
# --- 13.863832235336304 сек ---
# Средний доход: -8.50 к эпизоду 192, фрейм 3007107, eps 0.05
# --- 17.863765478134155 сек ---
# Средний доход: -6.60 к эпизоду 194, фрейм 3011433, eps 0.05
# --- 15.238441228866577 сек ---
# Net updated!
# Средний доход: -7.20 к эпизоду 196, фрейм 3016543, eps 0.05
# --- 17.928075075149536 сек ---
# Net saved!
# Средний доход: -6.80 к эпизоду 198, фрейм 3021019, eps 0.05
# --- 15.855406522750854 сек ---

# %% [markdown]
# Тест обученной модели.

# %%
agent = DQNAgent(env, model, model_target)

agent.Q_train = torch.load('savedModels/pong_py_'+str(2000000)+'.pkl',map_location=torch.device('cpu'), weights_only=False).to(device)
agent.Q_train.eval()
agent.Q_target = torch.load('savedModels/pong_py_'+str(2000000)+'.pkl',map_location=torch.device('cpu'), weights_only=False).to(device)
agent.Q_target.eval()
# Out:
# QNetwork(
#   (l1): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4), padding=(2, 2))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#   )
#   (l2): Sequential(
#     (0): Linear(in_features=7744, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=6, bias=True)
#   )
# )

# %%
agent.epsilon = 0.01

# %%
env = make_env("ALE/Pong-v5", render = 'human')
env = gym.wrappers.RecordEpisodeStatistics(env)

state, _ = env.reset()

while True:
    state, reward, terminated, truncated, _ = env.step(agent.best_action(state)) 
    if terminated or truncated:
        break
        
print("Доход:", env.return_queue[-1])
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 7
#       4 state, _ = env.reset()
#       6 while True:
# ----> 7     state, reward, terminated, truncated, _ = env.step(agent.best_action(state))
#       8     if terminated or truncated:
#       9         break
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:513, in RecordEpisodeStatistics.step(self, action)
#     509 def step(
#     510     self, action: ActType
#     511 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     512     """Steps through the environment, recording the episode statistics."""
# --> 513     obs, reward, terminated, truncated, info = super().step(action)
#     515     self.episode_returns += reward
#     516     self.episode_lengths += 1
#
# File D:\anaconda3\Lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\stateful_observation.py:416, in FrameStackObservation.step(self, action)
#     405 def step(
#     406     self, action: WrapperActType
#     407 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     408     """Steps through the environment, appending the observation to the frame buffer.
#     409
#     410     Args:
#    (...)
#     414         Stacked observations, reward, terminated, truncated, and info from the environment
#     415     """
# --> 416     obs, reward, terminated, truncated, info = self.env.step(action)
#     417     self.obs_queue.append(obs)
#     419     updated_obs = deepcopy(
#     420         concatenate(self.env.observation_space, self.obs_queue, self.stacked_obs)
#     421     )
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\atari_preprocessing.py:162, in AtariPreprocessing.step(self, action)
#     159 total_reward, terminated, truncated, info = 0.0, False, False, {}
#     161 for t in range(self.frame_skip):
# --> 162     _, reward, terminated, truncated, info = self.env.step(action)
#     163     total_reward += reward
#     164     self.game_over = terminated
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File D:\anaconda3\Lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File D:\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File D:\anaconda3\Lib\site-packages\ale_py\env.py:299, in AtariEnv.step(self, action)
#     297 reward = 0.0
#     298 for _ in range(frameskip):
# --> 299     reward += self.ale.act(action_idx, strength)
#     301 is_terminal = self.ale.game_over(with_truncation=False)
#     302 is_truncated = self.ale.game_truncated()
#
# KeyboardInterrupt:

# %%
torch.save(agent.Q_target, 'savedModels/pong_py_'+str(2500000)+'.pkl')

# %%
with open('logs/gains_pong_2.txt') as file:
    file_contents = file.read()
    file.close()

f1 = file_contents.split()
gains = []
for w in f1[1:]:
    gains.append(float(w))

# %%
import matplotlib.pyplot as plt
import numpy as np


y_ticks = np.arange(-21.0,21.0,2.0)
plt.yticks(y_ticks, y_ticks)
plt.plot(gains)
plt.show()
